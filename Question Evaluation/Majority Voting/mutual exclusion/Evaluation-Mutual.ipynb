# %%
import pandas as pd

# %%
## read from existing results :
mutual = pd.read_csv("Task13-P-U-Mutual_Exclusion_train.csv",sep=',')
print(mutual.columns)
mutual
# Out:
# Index(['Question_Id', 'Context', 'Original_Question', 'Original_Answer',
#        'Modified_Question', 'O-Q model2 answer span', 'O-Q model2 start',
#        'O-Q model2 end', 'O-Q model2 score', 'O-Q model4 answer span',
#        'O-Q model4 start', 'O-Q model4 end', 'O-Q model4 score',
#        'O-Q electra answer span', 'O-Q electra start', 'O-Q electra end',
#        'O-Q electra score', 'O-Q roberta answer span', 'O-Q roberta start',
#        'O-Q roberta end', 'O-Q roberta score', 'O-Q sgnet answer span',
#        'O-Q retro answer span', 'P-U model2 answer span', 'P-U model2 start',
#        'P-U model2 end', 'P-U model2 score', 'P-U model4 answer span',
#        'P-U model4 start', 'P-U model4 end', 'P-U model4 score',
#        'P-U electra answer span', 'P-U electra start', 'P-U electra end',
#        'P-U electra score', 'P-U roberta answer span', 'P-U roberta start',
#        'P-U roberta end', 'P-U roberta score', 'P-U retro answer span',
#        'P-U SgNet answer span'],
#       dtype='object')
# /tmp/ipykernel_1622344/2928536146.py:2: DtypeWarning: Columns (21,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   mutual = pd.read_csv("Task13-P-U-Mutual_Exclusion_train.csv",sep=',')
#                     Question_Id  \
# 0      56be85543aeaaa14008c9063
# 1      56be85543aeaaa14008c9066
# 2      56bf6b0f3aeaaa14008c9601
# 3      56bf6b0f3aeaaa14008c9602
# 4      56bf6b0f3aeaaa14008c9605
# ...                         ...
# 42702  5735d1a86c16ec1900b92833
# 42703  5735d1a86c16ec1900b92834
# 42704  5735d259012e2f140011a09d
# 42705  5735d259012e2f140011a09f
# 42706  5735d259012e2f140011a0a0
#
#                                                  Context  \
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# ...                                                  ...
# 42702  The main international airport serving Kathman...
# 42703  The main international airport serving Kathman...
# 42704  Kathmandu Metropolitan City (KMC), in order to...
# 42705  Kathmandu Metropolitan City (KMC), in order to...
# 42706  Kathmandu Metropolitan City (KMC), in order to...
#
#                                        Original_Question    Original_Answer  \
# 0               When did Beyonce start becoming popular?  in the late 1990s
# 1      When did Beyonce leave Destiny's Child and bec...               2003
# 2          In what city and state did Beyonce  grow up?      Houston, Texas
# 3             In which decade did Beyonce become famous?         late 1990s
# 4                 Who managed the Destiny's Child group?     Mathew Knowles
# ...                                                  ...                ...
# 42702  How many airlines use Tribhuvan International ...                 22
# 42703  From what city does Arkefly offer nonstop flig...          Amsterdam
# 42704  In what US state did Kathmandu first establish...             Oregon
# 42705  With what Belorussian city does Kathmandu have...              Minsk
# 42706  In what year did Kathmandu create its initial ...               1975
#
#                                        Modified_Question  \
# 0      When on in the late 1990s did Beyonce start be...
# 1      When on 2003 did Beyonce leave Destiny's Child...
# 2      Where in Houston, Texas what city and state di...
# 3      When on late 1990s which decade did Beyonce be...
# 4      How did Mathew Knowles managed the Destiny's C...
# ...                                                  ...
# 42702  What 22 airlines use Tribhuvan International f...
# 42703  Where in Amsterdam what city does Arkefly offe...
# 42704  Where in Oregon what US state did Kathmandu fi...
# 42705  Where in Minsk what Belorussian city does Kath...
# 42706  When on 1975 what year did Kathmandu create it...
#
#       O-Q model2 answer span  O-Q model2 start  O-Q model2 end  \
# 0                 late 1990s               275             286
# 1                    (2003),               524             532
# 2            Houston, Texas,               165             181
# 3                      1990s               280             286
# 4            Mathew Knowles,               359             375
# ...                      ...               ...             ...
# 42702                     22               296             299
# 42703              Amsterdam               697             707
# 42704                Oregon,               228             236
# 42705                  Minsk               475             481
# 42706                   1975               198             203
#
#        O-Q model2 score O-Q model4 answer span  ...  P-U electra answer span  \
# 0              0.636688             late 1990s  ...         Destiny's Child.
# 1              0.942531                   2003  ...      Dangerously in Love
# 2              0.576137                  Texas  ...                  Houston
# 3              0.666362                  1990s  ...                    1990s
# 4              0.469837         Mathew Knowles  ...               her father
# ...                 ...                    ...  ...                      ...
# 42702          0.741945                     22  ...                 Istanbul
# 42703          0.990591              Amsterdam  ...                Kathmandu
# 42704          0.995021                 Oregon  ...                   Eugene
# 42705          0.972188                  Minsk  ...                    Minsk
# 42706          0.996814                   1975  ...                     1975
#
#        P-U electra start  P-U electra end P-U electra score  \
# 0                    320              336          0.485786
# 1                    505              524          0.993189
# 2                    166              173          0.488683
# 3                    281              286          0.700807
# 4                    348              358          0.890356
# ...                  ...              ...               ...
# 42702                414              422          0.003750
# 42703                683              692          0.041974
# 42704                221              227          0.996033
# 42705                476              481          0.990540
# 42706                199              203          0.995461
#
#        P-U roberta answer span  P-U roberta start  P-U roberta end  \
# 0                   late 1990s                276              286
# 1                         2003                526              530
# 2                      Beyoncé                  0                7
# 3                   late 1990s                276              286
# 4        Managed by her father                337              358
# ...                        ...                ...              ...
# 42702                       22                297              299
# 42703                Amsterdam                698              707
# 42704                   Eugene                221              227
# 42705                    Minsk                476              481
# 42706                     1975                199              203
#
#       P-U roberta score                              P-U retro answer span  \
# 0          4.000321e-02                                    destiny's child
# 1          1.217182e-01                                            (2003),
# 2          4.421160e-02                                     houston, texas
# 3          2.667600e-01                                                NaN
# 4          9.785921e-05  became one of the world's best-selling girl gr...
# ...                 ...                                                ...
# 42702      2.646521e-03                                              [SEP]
# 42703      9.963666e-09                                          amsterdam
# 42704      9.717197e-01                                             eugene
# 42705      1.543661e-02                                              minsk
# 42706      6.293374e-01                                               1975
#
#               P-U SgNet answer span
# 0                                in
# 1      record producer and actress.
# 2                 the late 1990s as
# 3                        girl-group
# 4                           singles
# ...                             ...
# 42702                           NaN
# 42703                           NaN
# 42704                           NaN
# 42705                           NaN
# 42706                         empty
#
# [42707 rows x 41 columns]

# %% [markdown]
# # Cleaning Model's answer

# %%
import re

def preprocess_text2(text):
    if not pd.isna(text): 
        # Remove special characters from the left side
        text = re.sub(r'^\W+', '', text)

        # Remove special characters from the right side
        text = re.sub(r'\W+$', '', text)
        return text
    else: ## it's nan
        return ''
    
    
def preprocess_text(text):
    if not pd.isna(text): 
        return text
    else: ## it's nan
        return ''

text = "(2003)!,"
processed_text = preprocess_text(text)
print(processed_text)
# Out:
# (2003)!,

# %%
### Cleaning the result of models
import ast
Cln_orgQ_model2 = []
Cln_orgQ_model4 = []
Cln_orgQ_electra = []
Cln_orgQ_roberta = []
Cln_orgQ_sgnet = []
Cln_orgQ_retro = []

Cln_potUQ_model2 = []
Cln_potUQ_model4 = []
Cln_potUQ_electra = []
Cln_potUQ_roberta = []
Cln_potUQ_sgnet = []
Cln_potUQ_retro = []

for index, row in mutual.iterrows():
    if index % 10000 == 0:
        print(index)
    
    original_question_model2 = row['O-Q model2 answer span']
    original_question_model4 = row['O-Q model4 answer span']
    original_question_electra = row['O-Q electra answer span']
    original_question_roberta = row['O-Q roberta answer span']
    original_question_sgnet = row['O-Q sgnet answer span']
    original_question_retro = row['O-Q retro answer span']
    
    potentialU_question_model2 = row['P-U model2 answer span']
    potentialU_question_model4 = row['P-U model4 answer span']
    potentialU_question_electra = row['P-U electra answer span']
    potentialU_question_roberta = row['P-U roberta answer span']
    potentialU_question_sgnet = row['P-U SgNet answer span']
    potentialU_question_retro = row['P-U retro answer span']
    
    
    Cln_orgQ_model2.append(preprocess_text(original_question_model2))
    Cln_orgQ_model4.append(preprocess_text(original_question_model4))
    Cln_orgQ_electra.append(preprocess_text(original_question_electra))
    Cln_orgQ_roberta.append(preprocess_text(original_question_roberta))
    Cln_orgQ_sgnet.append(preprocess_text(original_question_sgnet))
    Cln_orgQ_retro.append(preprocess_text(original_question_retro))
    
    Cln_potUQ_model2.append(preprocess_text(potentialU_question_model2))
    Cln_potUQ_model4.append(preprocess_text(potentialU_question_model4))
    Cln_potUQ_electra.append(preprocess_text(potentialU_question_electra))
    Cln_potUQ_roberta.append(preprocess_text(potentialU_question_roberta))
    Cln_potUQ_sgnet.append(preprocess_text(potentialU_question_sgnet))
    Cln_potUQ_retro.append(preprocess_text(potentialU_question_retro))

    
      
mutual['Cln_orgQ_model2'] = Cln_orgQ_model2
mutual['Cln_orgQ_model4'] = Cln_orgQ_model4
mutual['Cln_orgQ_electra'] = Cln_orgQ_electra
mutual['Cln_orgQ_roberta'] = Cln_orgQ_roberta
mutual['Cln_orgQ_sgnet'] = Cln_orgQ_sgnet
mutual['Cln_orgQ_retro'] = Cln_orgQ_retro


mutual['Cln_potUQ_model2'] = Cln_potUQ_model2
mutual['Cln_potUQ_model4'] = Cln_potUQ_model4
mutual['Cln_potUQ_electra'] = Cln_potUQ_electra
mutual['Cln_potUQ_roberta'] = Cln_potUQ_roberta
mutual['Cln_potUQ_sgnet'] = Cln_potUQ_sgnet
mutual['Cln_potUQ_retro'] = Cln_potUQ_retro

# Specify the desired column order
new_column_order = [
    'Question_Id', 'Context', 'Original_Question', 'Original_Answer',
       'Modified_Question', 'O-Q model2 answer span', 'Cln_orgQ_model2',
       'O-Q model2 start', 'O-Q model2 end', 'O-Q model2 score',
       'O-Q model4 answer span', 'Cln_orgQ_model4', 'O-Q model4 start', 'O-Q model4 end',
       'O-Q model4 score', 'O-Q electra answer span','Cln_orgQ_electra', 'O-Q electra start',
       'O-Q electra end', 'O-Q electra score', 'O-Q roberta answer span', 'Cln_orgQ_roberta',
       'O-Q roberta start', 'O-Q roberta end', 'O-Q roberta score',
       'O-Q sgnet answer span', 'Cln_orgQ_sgnet' ,'O-Q retro answer span', 'Cln_orgQ_retro',
       'P-U model2 answer span', 'Cln_potUQ_model2', 'P-U model2 start', 'P-U model2 end',
       'P-U model2 score', 'P-U model4 answer span', 'Cln_potUQ_model4', 'P-U model4 start',
       'P-U model4 end', 'P-U model4 score', 'P-U electra answer span', 'Cln_potUQ_electra',
       'P-U electra start', 'P-U electra end', 'P-U electra score',
       'P-U roberta answer span', 'Cln_potUQ_roberta', 'P-U roberta start', 'P-U roberta end',
       'P-U roberta score', 'P-U SgNet answer span', 'Cln_potUQ_sgnet', 'P-U retro answer span', 'Cln_potUQ_retro'
    
]



       
# Reorder the columns in the DataFrame
mutual = mutual[new_column_order]


mutual
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
#                     Question_Id  \
# 0      56be85543aeaaa14008c9063
# 1      56be85543aeaaa14008c9066
# 2      56bf6b0f3aeaaa14008c9601
# 3      56bf6b0f3aeaaa14008c9602
# 4      56bf6b0f3aeaaa14008c9605
# ...                         ...
# 42702  5735d1a86c16ec1900b92833
# 42703  5735d1a86c16ec1900b92834
# 42704  5735d259012e2f140011a09d
# 42705  5735d259012e2f140011a09f
# 42706  5735d259012e2f140011a0a0
#
#                                                  Context  \
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# ...                                                  ...
# 42702  The main international airport serving Kathman...
# 42703  The main international airport serving Kathman...
# 42704  Kathmandu Metropolitan City (KMC), in order to...
# 42705  Kathmandu Metropolitan City (KMC), in order to...
# 42706  Kathmandu Metropolitan City (KMC), in order to...
#
#                                        Original_Question    Original_Answer  \
# 0               When did Beyonce start becoming popular?  in the late 1990s
# 1      When did Beyonce leave Destiny's Child and bec...               2003
# 2          In what city and state did Beyonce  grow up?      Houston, Texas
# 3             In which decade did Beyonce become famous?         late 1990s
# 4                 Who managed the Destiny's Child group?     Mathew Knowles
# ...                                                  ...                ...
# 42702  How many airlines use Tribhuvan International ...                 22
# 42703  From what city does Arkefly offer nonstop flig...          Amsterdam
# 42704  In what US state did Kathmandu first establish...             Oregon
# 42705  With what Belorussian city does Kathmandu have...              Minsk
# 42706  In what year did Kathmandu create its initial ...               1975
#
#                                        Modified_Question  \
# 0      When on in the late 1990s did Beyonce start be...
# 1      When on 2003 did Beyonce leave Destiny's Child...
# 2      Where in Houston, Texas what city and state di...
# 3      When on late 1990s which decade did Beyonce be...
# 4      How did Mathew Knowles managed the Destiny's C...
# ...                                                  ...
# 42702  What 22 airlines use Tribhuvan International f...
# 42703  Where in Amsterdam what city does Arkefly offe...
# 42704  Where in Oregon what US state did Kathmandu fi...
# 42705  Where in Minsk what Belorussian city does Kath...
# 42706  When on 1975 what year did Kathmandu create it...
#
#       O-Q model2 answer span   Cln_orgQ_model2  O-Q model2 start  \
# 0                 late 1990s        late 1990s               275
# 1                    (2003),           (2003),               524
# 2            Houston, Texas,   Houston, Texas,               165
# 3                      1990s             1990s               280
# 4            Mathew Knowles,   Mathew Knowles,               359
# ...                      ...               ...               ...
# 42702                     22                22               296
# 42703              Amsterdam         Amsterdam               697
# 42704                Oregon,           Oregon,               228
# 42705                  Minsk             Minsk               475
# 42706                   1975              1975               198
#
#        O-Q model2 end  O-Q model2 score  ... P-U electra score  \
# 0                 286          0.636688  ...          0.485786
# 1                 532          0.942531  ...          0.993189
# 2                 181          0.576137  ...          0.488683
# 3                 286          0.666362  ...          0.700807
# 4                 375          0.469837  ...          0.890356
# ...               ...               ...  ...               ...
# 42702             299          0.741945  ...          0.003750
# 42703             707          0.990591  ...          0.041974
# 42704             236          0.995021  ...          0.996033
# 42705             481          0.972188  ...          0.990540
# 42706             203          0.996814  ...          0.995461
#
#       P-U roberta answer span      Cln_potUQ_roberta  P-U roberta start  \
# 0                  late 1990s             late 1990s                276
# 1                        2003                   2003                526
# 2                     Beyoncé                Beyoncé                  0
# 3                  late 1990s             late 1990s                276
# 4       Managed by her father  Managed by her father                337
# ...                       ...                    ...                ...
# 42702                      22                     22                297
# 42703               Amsterdam              Amsterdam                698
# 42704                  Eugene                 Eugene                221
# 42705                   Minsk                  Minsk                476
# 42706                    1975                   1975                199
#
#        P-U roberta end P-U roberta score         P-U SgNet answer span  \
# 0                  286      4.000321e-02                            in
# 1                  530      1.217182e-01  record producer and actress.
# 2                    7      4.421160e-02             the late 1990s as
# 3                  286      2.667600e-01                    girl-group
# 4                  358      9.785921e-05                       singles
# ...                ...               ...                           ...
# 42702              299      2.646521e-03                           NaN
# 42703              707      9.963666e-09                           NaN
# 42704              227      9.717197e-01                           NaN
# 42705              481      1.543661e-02                           NaN
# 42706              203      6.293374e-01                         empty
#
#                     Cln_potUQ_sgnet  \
# 0                                in
# 1      record producer and actress.
# 2                 the late 1990s as
# 3                        girl-group
# 4                           singles
# ...                             ...
# 42702
# 42703
# 42704
# 42705
# 42706                         empty
#
#                                    P-U retro answer span  \
# 0                                        destiny's child
# 1                                                (2003),
# 2                                         houston, texas
# 3                                                    NaN
# 4      became one of the world's best-selling girl gr...
# ...                                                  ...
# 42702                                              [SEP]
# 42703                                          amsterdam
# 42704                                             eugene
# 42705                                              minsk
# 42706                                               1975
#
#                                          Cln_potUQ_retro
# 0                                        destiny's child
# 1                                                (2003),
# 2                                         houston, texas
# 3
# 4      became one of the world's best-selling girl gr...
# ...                                                  ...
# 42702                                              [SEP]
# 42703                                          amsterdam
# 42704                                             eugene
# 42705                                              minsk
# 42706                                               1975
#
# [42707 rows x 53 columns]

# %% [markdown]
# # EM and unanswerability

# %%
EM_dataset_Cln_orgQ_model2 = []
EM_dataset_Cln_orgQ_model4 = []
EM_dataset_Cln_orgQ_electra = []
EM_dataset_Cln_orgQ_roberta = []
EM_dataset_Cln_orgQ_sgnet = []
EM_dataset_Cln_orgQ_retro = []

EM_dataset_Cln_potUQ_model2 = []
EM_dataset_Cln_potUQ_model4 = []
EM_dataset_Cln_potUQ_electra = []
EM_dataset_Cln_potUQ_roberta = []
Null_EM_dataset_Cln_potUQ_sgnet = []
Null_EM_dataset_Cln_potUQ_retro = []
### for unanswerability
un_potUQ_model2 = []
un_potUQ_model4 = []
un_potUQ_electra = []
un_potUQ_roberta = []
un_potUQ_sgnet = []
un_potUQ_retro = []


for index, row in mutual.iterrows():
    if index % 100000 == 0:
        print(index)
        
    original_answer_in_dataset = row['Original_Answer']

    original_question_model2 = row['Cln_orgQ_model2']
    original_question_model4 = row['Cln_orgQ_model4']
    original_question_electra = row['Cln_orgQ_electra']
    original_question_roberta = row['Cln_orgQ_roberta']
    original_question_sgnet = row['Cln_orgQ_sgnet']
    original_question_retro = row['Cln_orgQ_retro']
    
    potentialU_question_sgnet = row['Cln_potUQ_sgnet']
    potentialU_question_retro = row['Cln_potUQ_retro']
    potentialU_questionS_model2 = row['P-U model2 score']
    potentialU_questionS_model4 = row['P-U model4 score']
    potentialU_questionS_electra = row['P-U electra score']
    potentialU_questionS_roberta = row['P-U roberta score']
    



    if original_answer_in_dataset == original_question_model2:  # EM checking (dataset , model on org_q)
        EM_dataset_Cln_orgQ_model2.append(1)
    else:
        EM_dataset_Cln_orgQ_model2.append(0)
    
    if original_answer_in_dataset == original_question_model4:
        EM_dataset_Cln_orgQ_model4.append(1)
    else:
        EM_dataset_Cln_orgQ_model4.append(0)
    
    if original_answer_in_dataset == original_question_electra:
        EM_dataset_Cln_orgQ_electra.append(1)
    else:
        EM_dataset_Cln_orgQ_electra.append(0)
        
    if original_answer_in_dataset == original_question_roberta:
        EM_dataset_Cln_orgQ_roberta.append(1)
    else:
        EM_dataset_Cln_orgQ_roberta.append(0)
    
    if original_answer_in_dataset == original_question_sgnet:
        EM_dataset_Cln_orgQ_sgnet.append(1)
    else:
        EM_dataset_Cln_orgQ_sgnet.append(0)
        
    if original_answer_in_dataset == original_question_retro:
        EM_dataset_Cln_orgQ_retro.append(1)
    else:
        EM_dataset_Cln_orgQ_retro.append(0)
        
    if original_answer_in_dataset == potentialU_question_model2: ## EM checking (dataset, model on p-u_q)
        EM_dataset_Cln_potUQ_model2.append(1)
    else:
        EM_dataset_Cln_potUQ_model2.append(0)
    
    if original_answer_in_dataset == potentialU_question_model4:
        EM_dataset_Cln_potUQ_model4.append(1)
    else:
        EM_dataset_Cln_potUQ_model4.append(0)
    
    if original_answer_in_dataset == potentialU_question_electra:
        EM_dataset_Cln_potUQ_electra.append(1)
    else:
        EM_dataset_Cln_potUQ_electra.append(0)
        
    if original_answer_in_dataset == potentialU_question_roberta:
        EM_dataset_Cln_potUQ_roberta.append(1)
    else:
        EM_dataset_Cln_potUQ_roberta.append(0)
    
    Null_EM_dataset_Cln_potUQ_sgnet.append(100)
    Null_EM_dataset_Cln_potUQ_retro.append(100)

    if potentialU_questionS_model2 <= 0.096476303 : # unanswerablity checking
        un_potUQ_model2.append(0)  #unanswerable
    else:
        un_potUQ_model2.append(1)  #answerable
    
    if potentialU_questionS_model4 <= 0.15272566:
        un_potUQ_model4.append(0) #unanswerable
    else:
        un_potUQ_model4.append(1) #answerable
    
    if potentialU_questionS_electra <= 0.141489303:
        un_potUQ_electra.append(0) #unanswerable
    else:
        un_potUQ_electra.append(1) #answerable
        
    if potentialU_questionS_roberta <= 0.063691394:
        un_potUQ_roberta.append(0) #unanswerable
    else: 
        un_potUQ_roberta.append(1) #answerable
    
    if potentialU_question_sgnet == "": 
        un_potUQ_sgnet.append(0) #unanswerable
    else:
        un_potUQ_sgnet.append(1) #answerable
        
    if potentialU_question_retro == "" or potentialU_question_retro.startswith("[SEP]") or potentialU_question_retro == "'" or potentialU_question_retro == "," or potentialU_question_retro == "<No Answer>. The question is not answerable according to the context." or potentialU_question_retro == "<unk>=0" :
        un_potUQ_retro.append(0) #unanswerable
    else:
        un_potUQ_retro.append(1) #answerable
        
mutual['EM dataset with clean orgQ_model2'] = EM_dataset_Cln_orgQ_model2
mutual['EM dataset with clean orgQ_model4'] = EM_dataset_Cln_orgQ_model4
mutual['EM dataset with clean orgQ_electra'] = EM_dataset_Cln_orgQ_electra
mutual['EM dataset with clean orgQ_roberta'] = EM_dataset_Cln_orgQ_roberta
mutual['EM dataset with clean orgQ_sgnet'] = EM_dataset_Cln_orgQ_sgnet
mutual['EM dataset with clean orgQ_retro'] = EM_dataset_Cln_orgQ_retro


mutual['EM dataset with clean potentailUQ_model2'] = EM_dataset_Cln_potUQ_model2
mutual['EM dataset with clean potentailUQ_model4'] = EM_dataset_Cln_potUQ_model4
mutual['EM dataset with clean potentailUQ_electra'] = EM_dataset_Cln_potUQ_electra
mutual['EM dataset with clean potentailUQ_roberta'] = EM_dataset_Cln_potUQ_roberta
mutual['NULL EM dataset with clean potentailUQ_sgnet'] = Null_EM_dataset_Cln_potUQ_sgnet
mutual['NULL EM dataset with clean potentailUQ_retro'] = Null_EM_dataset_Cln_potUQ_retro


mutual['unanswerability potentailUQ_model2'] = un_potUQ_model2
mutual['unanswerability potentailUQ_model4'] = un_potUQ_model4
mutual['unanswerability potentailUQ_electra'] = un_potUQ_electra
mutual['unanswerability potentailUQ_roberta'] = un_potUQ_roberta
mutual['unanswerability potentailUQ_sgnet'] = un_potUQ_sgnet
mutual['unanswerability potentailUQ_retro'] = un_potUQ_retro

new_column_order = [
    'Question_Id', 'Context', 'Original_Question', 'Original_Answer',
    'Modified_Question', 'O-Q model2 answer span', 'Cln_orgQ_model2', 'EM dataset with clean orgQ_model2',
    'O-Q model2 start', 'O-Q model2 end', 'O-Q model2 score',
    'O-Q model4 answer span', 'Cln_orgQ_model4','EM dataset with clean orgQ_model4' ,'O-Q model4 start', 'O-Q model4 end',
    'O-Q model4 score', 'O-Q electra answer span','Cln_orgQ_electra', 'EM dataset with clean orgQ_electra', 'O-Q electra start',
    'O-Q electra end', 'O-Q electra score', 'O-Q roberta answer span', 'Cln_orgQ_roberta', 'EM dataset with clean orgQ_roberta',
    'O-Q roberta start', 'O-Q roberta end', 'O-Q roberta score',
    'O-Q sgnet answer span', 'Cln_orgQ_sgnet', 'EM dataset with clean orgQ_sgnet' ,'O-Q retro answer span', 'Cln_orgQ_retro', 'EM dataset with clean orgQ_retro',
    'P-U model2 answer span', 'Cln_potUQ_model2','EM dataset with clean potentailUQ_model2','unanswerability potentailUQ_model2' ,'P-U model2 start', 'P-U model2 end',
    'P-U model2 score', 'P-U model4 answer span', 'Cln_potUQ_model4','EM dataset with clean potentailUQ_model4','unanswerability potentailUQ_model4', 'P-U model4 start',
    'P-U model4 end', 'P-U model4 score', 'P-U electra answer span', 'Cln_potUQ_electra', 'EM dataset with clean potentailUQ_electra','unanswerability potentailUQ_electra',
    'P-U electra start', 'P-U electra end', 'P-U electra score',
    'P-U roberta answer span', 'Cln_potUQ_roberta','EM dataset with clean potentailUQ_roberta','unanswerability potentailUQ_roberta' ,'P-U roberta start', 'P-U roberta end',
    'P-U roberta score', 'P-U SgNet answer span', 'Cln_potUQ_sgnet','NULL EM dataset with clean potentailUQ_sgnet' ,'unanswerability potentailUQ_sgnet','P-U retro answer span', 'Cln_potUQ_retro',
    'NULL EM dataset with clean potentailUQ_retro', 'unanswerability potentailUQ_retro'
    
]



# Reorder the columns in the DataFrame
mutual = mutual[new_column_order]


mutual
# Out:
# 0
# /tmp/ipykernel_1622344/1955004938.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['EM dataset with clean orgQ_model2'] = EM_dataset_Cln_orgQ_model2
# /tmp/ipykernel_1622344/1955004938.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['EM dataset with clean orgQ_model4'] = EM_dataset_Cln_orgQ_model4
# /tmp/ipykernel_1622344/1955004938.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['EM dataset with clean orgQ_electra'] = EM_dataset_Cln_orgQ_electra
# /tmp/ipykernel_1622344/1955004938.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['EM dataset with clean orgQ_roberta'] = EM_dataset_Cln_orgQ_roberta
# /tmp/ipykernel_1622344/1955004938.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['EM dataset with clean orgQ_sgnet'] = EM_dataset_Cln_orgQ_sgnet
# /tmp/ipykernel_1622344/1955004938.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['EM dataset with clean orgQ_retro'] = EM_dataset_Cln_orgQ_retro
# /tmp/ipykernel_1622344/1955004938.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['EM dataset with clean potentailUQ_model2'] = EM_dataset_Cln_potUQ_model2
# /tmp/ipykernel_1622344/1955004938.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['EM dataset with clean potentailUQ_model4'] = EM_dataset_Cln_potUQ_model4
# /tmp/ipykernel_1622344/1955004938.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['EM dataset with clean potentailUQ_electra'] = EM_dataset_Cln_potUQ_electra
# /tmp/ipykernel_1622344/1955004938.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['EM dataset with clean potentailUQ_roberta'] = EM_dataset_Cln_potUQ_roberta
# /tmp/ipykernel_1622344/1955004938.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['NULL EM dataset with clean potentailUQ_sgnet'] = Null_EM_dataset_Cln_potUQ_sgnet
# /tmp/ipykernel_1622344/1955004938.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['NULL EM dataset with clean potentailUQ_retro'] = Null_EM_dataset_Cln_potUQ_retro
# /tmp/ipykernel_1622344/1955004938.py:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['unanswerability potentailUQ_model2'] = un_potUQ_model2
# /tmp/ipykernel_1622344/1955004938.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['unanswerability potentailUQ_model4'] = un_potUQ_model4
# /tmp/ipykernel_1622344/1955004938.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['unanswerability potentailUQ_electra'] = un_potUQ_electra
# /tmp/ipykernel_1622344/1955004938.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['unanswerability potentailUQ_roberta'] = un_potUQ_roberta
# /tmp/ipykernel_1622344/1955004938.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['unanswerability potentailUQ_sgnet'] = un_potUQ_sgnet
# /tmp/ipykernel_1622344/1955004938.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutual['unanswerability potentailUQ_retro'] = un_potUQ_retro
#                     Question_Id  \
# 0      56be85543aeaaa14008c9063
# 1      56be85543aeaaa14008c9066
# 2      56bf6b0f3aeaaa14008c9601
# 3      56bf6b0f3aeaaa14008c9602
# 4      56bf6b0f3aeaaa14008c9605
# ...                         ...
# 42702  5735d1a86c16ec1900b92833
# 42703  5735d1a86c16ec1900b92834
# 42704  5735d259012e2f140011a09d
# 42705  5735d259012e2f140011a09f
# 42706  5735d259012e2f140011a0a0
#
#                                                  Context  \
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# ...                                                  ...
# 42702  The main international airport serving Kathman...
# 42703  The main international airport serving Kathman...
# 42704  Kathmandu Metropolitan City (KMC), in order to...
# 42705  Kathmandu Metropolitan City (KMC), in order to...
# 42706  Kathmandu Metropolitan City (KMC), in order to...
#
#                                        Original_Question    Original_Answer  \
# 0               When did Beyonce start becoming popular?  in the late 1990s
# 1      When did Beyonce leave Destiny's Child and bec...               2003
# 2          In what city and state did Beyonce  grow up?      Houston, Texas
# 3             In which decade did Beyonce become famous?         late 1990s
# 4                 Who managed the Destiny's Child group?     Mathew Knowles
# ...                                                  ...                ...
# 42702  How many airlines use Tribhuvan International ...                 22
# 42703  From what city does Arkefly offer nonstop flig...          Amsterdam
# 42704  In what US state did Kathmandu first establish...             Oregon
# 42705  With what Belorussian city does Kathmandu have...              Minsk
# 42706  In what year did Kathmandu create its initial ...               1975
#
#                                        Modified_Question  \
# 0      When on in the late 1990s did Beyonce start be...
# 1      When on 2003 did Beyonce leave Destiny's Child...
# 2      Where in Houston, Texas what city and state di...
# 3      When on late 1990s which decade did Beyonce be...
# 4      How did Mathew Knowles managed the Destiny's C...
# ...                                                  ...
# 42702  What 22 airlines use Tribhuvan International f...
# 42703  Where in Amsterdam what city does Arkefly offe...
# 42704  Where in Oregon what US state did Kathmandu fi...
# 42705  Where in Minsk what Belorussian city does Kath...
# 42706  When on 1975 what year did Kathmandu create it...
#
#       O-Q model2 answer span   Cln_orgQ_model2  \
# 0                 late 1990s        late 1990s
# 1                    (2003),           (2003),
# 2            Houston, Texas,   Houston, Texas,
# 3                      1990s             1990s
# 4            Mathew Knowles,   Mathew Knowles,
# ...                      ...               ...
# 42702                     22                22
# 42703              Amsterdam         Amsterdam
# 42704                Oregon,           Oregon,
# 42705                  Minsk             Minsk
# 42706                   1975              1975
#
#        EM dataset with clean orgQ_model2  O-Q model2 start  O-Q model2 end  \
# 0                                      0               275             286
# 1                                      0               524             532
# 2                                      0               165             181
# 3                                      0               280             286
# 4                                      0               359             375
# ...                                  ...               ...             ...
# 42702                                  1               296             299
# 42703                                  0               697             707
# 42704                                  0               228             236
# 42705                                  0               475             481
# 42706                                  1               198             203
#
#        ...  P-U roberta end P-U roberta score         P-U SgNet answer span  \
# 0      ...              286      4.000321e-02                            in
# 1      ...              530      1.217182e-01  record producer and actress.
# 2      ...                7      4.421160e-02             the late 1990s as
# 3      ...              286      2.667600e-01                    girl-group
# 4      ...              358      9.785921e-05                       singles
# ...    ...              ...               ...                           ...
# 42702  ...              299      2.646521e-03                           NaN
# 42703  ...              707      9.963666e-09                           NaN
# 42704  ...              227      9.717197e-01                           NaN
# 42705  ...              481      1.543661e-02                           NaN
# 42706  ...              203      6.293374e-01                         empty
#
#                     Cln_potUQ_sgnet  \
# 0                                in
# 1      record producer and actress.
# 2                 the late 1990s as
# 3                        girl-group
# 4                           singles
# ...                             ...
# 42702
# 42703
# 42704
# 42705
# 42706                         empty
#
#        NULL EM dataset with clean potentailUQ_sgnet  \
# 0                                               100
# 1                                               100
# 2                                               100
# 3                                               100
# 4                                               100
# ...                                             ...
# 42702                                           100
# 42703                                           100
# 42704                                           100
# 42705                                           100
# 42706                                           100
#
#        unanswerability potentailUQ_sgnet  \
# 0                                      1
# 1                                      1
# 2                                      1
# 3                                      1
# 4                                      1
# ...                                  ...
# 42702                                  0
# 42703                                  0
# 42704                                  0
# 42705                                  0
# 42706                                  1
#
#                                    P-U retro answer span  \
# 0                                        destiny's child
# 1                                                (2003),
# 2                                         houston, texas
# 3                                                    NaN
# 4      became one of the world's best-selling girl gr...
# ...                                                  ...
# 42702                                              [SEP]
# 42703                                          amsterdam
# 42704                                             eugene
# 42705                                              minsk
# 42706                                               1975
#
#                                          Cln_potUQ_retro  \
# 0                                        destiny's child
# 1                                                (2003),
# 2                                         houston, texas
# 3
# 4      became one of the world's best-selling girl gr...
# ...                                                  ...
# 42702                                              [SEP]
# 42703                                          amsterdam
# 42704                                             eugene
# 42705                                              minsk
# 42706                                               1975
#
#       NULL EM dataset with clean potentailUQ_retro  \
# 0                                              100
# 1                                              100
# 2                                              100
# 3                                              100
# 4                                              100
# ...                                            ...
# 42702                                          100
# 42703                                          100
# 42704                                          100
# 42705                                          100
# 42706                                          100
#
#        unanswerability potentailUQ_retro
# 0                                      1
# 1                                      1
# 2                                      1
# 3                                      0
# 4                                      1
# ...                                  ...
# 42702                                  0
# 42703                                  1
# 42704                                  1
# 42705                                  1
# 42706                                  1
#
# [42707 rows x 71 columns]

# %% [markdown]
# # Working on EM results

# %%
import pandas as pd
from tqdm import tqdm

# Define an empty list to hold the rows
rows = []

# Iterate through the DataFrame using iterrows
for index, row in tqdm(mutual.iterrows(), total=mutual.shape[0], desc="Processing rows"):
    if index % 100000 == 0: 
        print(index)

    qid = row['Question_Id']
    context = row['Context']
    org_question = row['Original_Question']
    org_answer = row['Original_Answer']
    pu_question = row['Modified_Question']

    model_data = [
        ('model 2', row['Cln_orgQ_model2'], row['Cln_potUQ_model2'], row['EM dataset with clean orgQ_model2'], row['EM dataset with clean potentailUQ_model2'],row['unanswerability potentailUQ_model2']),
        ('model 4', row['Cln_orgQ_model4'], row['Cln_potUQ_model4'], row['EM dataset with clean orgQ_model4'], row['EM dataset with clean potentailUQ_model4'],row['unanswerability potentailUQ_model4']),
        ('electra', row['Cln_orgQ_electra'], row['Cln_potUQ_electra'], row['EM dataset with clean orgQ_electra'], row['EM dataset with clean potentailUQ_electra'],row['unanswerability potentailUQ_electra']),
        ('roberta', row['Cln_orgQ_roberta'], row['Cln_potUQ_roberta'], row['EM dataset with clean orgQ_roberta'], row['EM dataset with clean potentailUQ_roberta'],row['unanswerability potentailUQ_roberta']),
        ('sgnet', row['Cln_orgQ_sgnet'], row['Cln_potUQ_sgnet'], row['EM dataset with clean orgQ_sgnet'], row['NULL EM dataset with clean potentailUQ_sgnet'],row['unanswerability potentailUQ_sgnet']),
        ('retro', row['Cln_orgQ_retro'], row['Cln_potUQ_retro'], row['EM dataset with clean orgQ_retro'], row['NULL EM dataset with clean potentailUQ_retro'],row['unanswerability potentailUQ_retro'])
    ]

    for model_name, org_output, pu_output, org_em, pu_em,un in model_data:
        row_data = [qid, context, org_question, org_answer, org_output, pu_question, pu_output, org_em, pu_em,un, model_name]
        rows.append(row_data)

# Convert the list of rows to a DataFrame
result_df = pd.DataFrame(rows, columns=['qid', 'context', 'original question in dataset', 'original answer span in dataset', 
                                        'output of model for original question', 'potentail_UQ question', 
                                        'output of model for potentail_UQ question', 
                                        'EM-dataset answer with model on orgQ', 'EM-dataset answer with model on potentialUQ', 'unanswerability on potential question',
                                        'model name'])

result_df
# Out:
# Processing rows:   5%|███▏                                                       | 2292/42707 [00:00<00:04, 8686.65it/s]
# 0
# Processing rows: 100%|█████████████████████████████████████████████████████████| 42707/42707 [00:03<00:00, 11982.53it/s]
#                              qid  \
# 0       56be85543aeaaa14008c9063
# 1       56be85543aeaaa14008c9063
# 2       56be85543aeaaa14008c9063
# 3       56be85543aeaaa14008c9063
# 4       56be85543aeaaa14008c9063
# ...                          ...
# 256237  5735d259012e2f140011a0a0
# 256238  5735d259012e2f140011a0a0
# 256239  5735d259012e2f140011a0a0
# 256240  5735d259012e2f140011a0a0
# 256241  5735d259012e2f140011a0a0
#
#                                                   context  \
# 0       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# ...                                                   ...
# 256237  Kathmandu Metropolitan City (KMC), in order to...
# 256238  Kathmandu Metropolitan City (KMC), in order to...
# 256239  Kathmandu Metropolitan City (KMC), in order to...
# 256240  Kathmandu Metropolitan City (KMC), in order to...
# 256241  Kathmandu Metropolitan City (KMC), in order to...
#
#                              original question in dataset  \
# 0                When did Beyonce start becoming popular?
# 1                When did Beyonce start becoming popular?
# 2                When did Beyonce start becoming popular?
# 3                When did Beyonce start becoming popular?
# 4                When did Beyonce start becoming popular?
# ...                                                   ...
# 256237  In what year did Kathmandu create its initial ...
# 256238  In what year did Kathmandu create its initial ...
# 256239  In what year did Kathmandu create its initial ...
# 256240  In what year did Kathmandu create its initial ...
# 256241  In what year did Kathmandu create its initial ...
#
#        original answer span in dataset output of model for original question  \
# 0                    in the late 1990s                            late 1990s
# 1                    in the late 1990s                            late 1990s
# 2                    in the late 1990s                     in the late 1990s
# 3                    in the late 1990s                            late 1990s
# 4                    in the late 1990s                                    in
# ...                                ...                                   ...
# 256237                            1975                                  1975
# 256238                            1975                                  1975
# 256239                            1975                                  1975
# 256240                            1975
# 256241                            1975                                  1975
#
#                                     potentail_UQ question  \
# 0       When on in the late 1990s did Beyonce start be...
# 1       When on in the late 1990s did Beyonce start be...
# 2       When on in the late 1990s did Beyonce start be...
# 3       When on in the late 1990s did Beyonce start be...
# 4       When on in the late 1990s did Beyonce start be...
# ...                                                   ...
# 256237  When on 1975 what year did Kathmandu create it...
# 256238  When on 1975 what year did Kathmandu create it...
# 256239  When on 1975 what year did Kathmandu create it...
# 256240  When on 1975 what year did Kathmandu create it...
# 256241  When on 1975 what year did Kathmandu create it...
#
#        output of model for potentail_UQ question  \
# 0                               Destiny's Child.
# 1                                           1981
# 2                               Destiny's Child.
# 3                                     late 1990s
# 4                                             in
# ...                                          ...
# 256237                                      1975
# 256238                                      1975
# 256239                                      1975
# 256240                                     empty
# 256241                                      1975
#
#         EM-dataset answer with model on orgQ  \
# 0                                          0
# 1                                          0
# 2                                          1
# 3                                          0
# 4                                          0
# ...                                      ...
# 256237                                     1
# 256238                                     1
# 256239                                     1
# 256240                                     0
# 256241                                     1
#
#         EM-dataset answer with model on potentialUQ  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                               100
# ...                                             ...
# 256237                                            1
# 256238                                            1
# 256239                                            1
# 256240                                          100
# 256241                                          100
#
#         unanswerability on potential question model name
# 0                                           1    model 2
# 1                                           0    model 4
# 2                                           1    electra
# 3                                           0    roberta
# 4                                           1      sgnet
# ...                                       ...        ...
# 256237                                      1    model 4
# 256238                                      1    electra
# 256239                                      1    roberta
# 256240                                      1      sgnet
# 256241                                      1      retro
#
# [256242 rows x 11 columns]

# %%
result_df.to_csv('20240704-forAllConditions_Mutual_Eval100.csv')
# result_df = pd.read_csv("20240704-forAllConditions_Mutual_Eval100.csv",sep=',')
# modified_Entity_Swap_df
print('percentages over all models')
model_name_counts = result_df['model name'].value_counts()
print(model_name_counts)
print("total row = " , len(result_df['model name']))
# Out:
# percentages over all models
# model name
# model 2    42707
# model 4    42707
# electra    42707
# roberta    42707
# sgnet      42707
# retro      42707
# Name: count, dtype: int64
# total row =  256242

# %%
import pandas as pd

# Group by 'qid' and 'potential_UQ question'
grouped = result_df.groupby(['qid', 'potentail_UQ question'])

# Initialize an empty list to hold the result
result_list = []

# Iterate over each group
for name, group in grouped:
    model_name_list = []
    sw = True
    qid, potential_UQ_question = name  # unpack the group name
    
    # Assume that context, original_question, and original_answer_span are the same for each group
    context = group.iloc[0]['context']
    original_question = group.iloc[0]['original question in dataset']
    original_answer_span = group.iloc[0]['original answer span in dataset']
    
    # Iterate through each row in the group
    for index, row in group.iterrows():
        EM_orgQ = row['EM-dataset answer with model on orgQ']
        EM_modifiedQ = row['EM-dataset answer with model on potentialUQ']
        unanswerability = row['unanswerability on potential question']
        
        #### New eval (1,0,0) for model2,model4,electra,roberta AND (1,0) for retro and sgnet   
        model_n = row['model name']
        if EM_orgQ ==1 : ### originalQ should be answered
            if model_n == 'model 2' or model_n == 'model 4' or model_n == 'electra' or model_n == 'roberta': 
                if EM_modifiedQ == 0 and unanswerability == 0:  ## if model couldn't answer it (low score , and em=0 for p-u), now let's consider this model
                    if row['model name'] not in model_name_list:
                        model_name_list.append(row['model name'])
            elif model_n == 'retro' or model_n == 'sgnet':
                if unanswerability == 0:  ## if model couldn't answer it (null or empty answer), now let's consider this model
                    if row['model name'] not in model_name_list:
                        model_name_list.append(row['model name'])
    
    # Add the result to the list
    result_list.append({
        'qid': qid,
        'context': context,
        'original_question': original_question,
        'original_answer_span': original_answer_span,
        'potential_UQ_question': potential_UQ_question,
        'model_name_list': model_name_list,
        'len': len(model_name_list)
    })

# Create a new DataFrame from the result list
new_df = pd.DataFrame(result_list)
new_df.to_csv('20240704-for10Conditions_Mutual_EVAL100.csv')
# Display the new DataFrame
display(new_df)
# Out:
#                             qid  \
# 0      56be85543aeaaa14008c9063
# 1      56be85543aeaaa14008c9066
# 2      56be86cf3aeaaa14008c9078
# 3      56be86cf3aeaaa14008c9079
# 4      56be88473aeaaa14008c9084
# ...                         ...
# 42702  57363293012e2f140011a218
# 42703  57363293012e2f140011a21a
# 42704  5736342b506b47140023658c
# 42705  5736342b506b47140023658d
# 42706  5736342b506b47140023658f
#
#                                                  context  \
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2      Following the disbandment of Destiny's Child i...
# 3      Following the disbandment of Destiny's Child i...
# 4      A self-described "modern-day feminist", Beyonc...
# ...                                                  ...
# 42702  Since 1934, the sale of Federal Duck Stamps ha...
# 42703  Since 1934, the sale of Federal Duck Stamps ha...
# 42704  The Arabian oryx, a species of large antelope,...
# 42705  The Arabian oryx, a species of large antelope,...
# 42706  The Arabian oryx, a species of large antelope,...
#
#                                        original_question  \
# 0               When did Beyonce start becoming popular?
# 1      When did Beyonce leave Destiny's Child and bec...
# 2                        Which artist did Beyonce marry?
# 3      To set the record for Grammys, how many did Be...
# 4      Which magazine declared her the most dominant ...
# ...                                                  ...
# 42702  How much land has the Duck Stamp Act help purc...
# 42703  What percent of sales are contributed by hunters?
# 42704               What is a species of large antelope?
# 42705  What did the large antelope species once inhabit?
# 42706          When did the Arabian oryx become extinct?
#
#                               original_answer_span  \
# 0                                in the late 1990s
# 1                                             2003
# 2                                            Jay Z
# 3                                              six
# 4                                           Forbes
# ...                                            ...
# 42702                              5,200,000 acres
# 42703                                 eighty-seven
# 42704                                 Arabian oryx
# 42705  much of the desert areas of the Middle East
# 42706                                         1972
#
#                                    potential_UQ_question  \
# 0      When on in the late 1990s did Beyonce start be...
# 1      When on 2003 did Beyonce leave Destiny's Child...
# 2                How did Jay Z artist did Beyonce marry?
# 3      What six the record for Grammys, how many did ...
# 4      How did Forbes magazine declared her the most ...
# ...                                                  ...
# 42702  What 5,200,000 acres land has the Duck Stamp A...
# 42703  When on eighty-seven percent of sales are cont...
# 42704  Where in Arabian oryx is a species of large an...
# 42705  Where in much of the desert areas of the Middl...
# 42706  When on 1972 did the Arabian oryx become extinct?
#
#                    model_name_list  len
# 0                               []    0
# 1                        [model 4]    1
# 2                        [model 4]    1
# 3                        [electra]    1
# 4                        [model 4]    1
# ...                            ...  ...
# 42702           [model 4, electra]    2
# 42703    [model 4, electra, retro]    3
# 42704           [electra, roberta]    2
# 42705  [model 4, electra, roberta]    3
# 42706             [electra, retro]    2
#
# [42707 rows x 7 columns]

# %%
filtered_df = new_df[new_df['len'] >= 4]
filtered_df.to_csv('20240704-Mutual-FinalUQ-EVAL100.csv')
filtered_df
# Out:
#                             qid  \
# 53     56bea8463aeaaa14008c91ac
# 155    56bf91c6a10cfb1400551183
# 235    56bfd6f7a10cfb1400551325
# 257    56bfe66ea10cfb1400551381
# 349    56cc36926d243a140015eed2
# ...                         ...
# 42609  5735c028e853931400426b39
# 42657  5735d1a86c16ec1900b92833
# 42682  573610e9012e2f140011a189
# 42685  573610e9012e2f140011a18c
# 42701  57363293012e2f140011a217
#
#                                                  context  \
# 53     In August, the couple attended the 2011 MTV Vi...
# 155    In November 2003, she embarked on the Dangerou...
# 235    Beyoncé has received numerous awards. As a sol...
# 257    In October 2014, Beyoncé signed a deal to laun...
# 349    Tibet was once a strong power contemporaneous ...
# ...                                                  ...
# 42609  Kathmandu is home to a number of museums and a...
# 42657  The main international airport serving Kathman...
# 42682  Hunting in the United States is not associated...
# 42685  Hunting in the United States is not associated...
# 42701  Since 1934, the sale of Federal Duck Stamps ha...
#
#                                        original_question  \
# 53     How many people watched the 2011 MTV Music Awa...
# 155    When did Destiny's Child get their star on the...
# 235    How many records has she sold with Destiny's C...
# 257                      When will the full line appear?
# 349    What year did Tang and Tibet sign a treaty to ...
# ...                                                  ...
# 42609  How many Monument Zones are present in the Kat...
# 42657  How many airlines use Tribhuvan International ...
# 42682  What percentage of Americans support legal hun...
# 42685                 Midwesterners hunted at what rate?
# 42701  How much money has been generated due to the D...
#
#         original_answer_span  \
# 53              12.4 million
# 155                    6-Mar
# 235               60 million
# 257                   16-Apr
# 349                      821
# ...                      ...
# 42609                  seven
# 42657                     22
# 42682  seventy-eight percent
# 42685         twelve percent
# 42701           $670 million
#
#                                    potential_UQ_question  \
# 53     What 12.4 million people watched the 2011 MTV ...
# 155    When on March 2006 did Destiny's Child get the...
# 235    What 60 million records has she sold with Dest...
# 257        When on April 2016 will the full line appear?
# 349    What 821 did Tang and Tibet sign a treaty to f...
# ...                                                  ...
# 42609  What seven Monument Zones are present in the K...
# 42657  What 22 airlines use Tribhuvan International f...
# 42682  How was the seventy-eight percent distributed ...
# 42685  How was the twelve percent distributed hunted ...
# 42701  How much money has been generated due to the d...
#
#                                    model_name_list  len
# 53              [model 4, electra, roberta, retro]    4
# 155             [model 4, electra, roberta, retro]    4
# 235             [model 4, electra, roberta, retro]    4
# 257             [model 4, electra, roberta, retro]    4
# 349           [model 2, model 4, electra, roberta]    4
# ...                                            ...  ...
# 42609           [model 4, electra, roberta, retro]    4
# 42657  [model 2, model 4, electra, roberta, retro]    5
# 42682           [model 4, electra, roberta, retro]    4
# 42685           [model 4, electra, roberta, retro]    4
# 42701           [model 4, electra, roberta, retro]    4
#
# [3221 rows x 7 columns]

# %%
# Define the conditions you want to check
conditions = [
    ('len >= 1', new_df['len'] >= 1),
    ('len == 3', new_df['len'] == 3),
    ('len == 4', new_df['len'] == 4),
    ('len == 5', new_df['len'] == 5),
    ('len == 6', new_df['len'] == 6),
    ('len >= 3', new_df['len'] >= 3),
    ('len >= 4', new_df['len'] >= 4),
    ('len >= 5', new_df['len'] >= 5)
]

# Initialize an empty dictionary to hold the results
condition_counts = {}

# Iterate over each condition
for condition_name, condition in conditions:
    # Filter the DataFrame based on the current condition
    filtered_df = new_df[condition]
    
    # Count the number of records that meet the condition
    count = filtered_df.shape[0]
    
    # Store the count in the dictionary
    condition_counts[condition_name] = count

# Display the counts for each condition
for condition_name, count in condition_counts.items():
    print(f"Number of records where {condition_name}: {count}")
# Out:
# Number of records where len >= 1: 31958
# Number of records where len == 3: 7670
# Number of records where len == 4: 2571
# Number of records where len == 5: 649
# Number of records where len == 6: 1
# Number of records where len >= 3: 10891
# Number of records where len >= 4: 3221
# Number of records where len >= 5: 650
