# %%
import pandas as pd

# %%
## read from existing results :
negation = pd.read_csv("Task13-P-U-Negation_train.csv",sep=',')
print(negation.columns)
negation
# Out:
# /tmp/ipykernel_1622476/991070602.py:2: DtypeWarning: Columns (21,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   negation = pd.read_csv("Task13-P-U-Negation_train.csv",sep=',')
# Index(['Question_Id', 'Context', 'Original_Question', 'Original_Answer',
#        'Modified_Question', 'O-Q model2 answer span', 'O-Q model2 start',
#        'O-Q model2 end', 'O-Q model2 score', 'O-Q model4 answer span',
#        'O-Q model4 start', 'O-Q model4 end', 'O-Q model4 score',
#        'O-Q electra answer span', 'O-Q electra start', 'O-Q electra end',
#        'O-Q electra score', 'O-Q roberta answer span', 'O-Q roberta start',
#        'O-Q roberta end', 'O-Q roberta score', 'O-Q sgnet answer span',
#        'O-Q retro answer span', 'P-U model2 answer span', 'P-U model2 start',
#        'P-U model2 end', 'P-U model2 score', 'P-U model4 answer span',
#        'P-U model4 start', 'P-U model4 end', 'P-U model4 score',
#        'P-U electra answer span', 'P-U electra start', 'P-U electra end',
#        'P-U electra score', 'P-U roberta answer span', 'P-U roberta start',
#        'P-U roberta end', 'P-U roberta score', 'P-U retro answer span',
#        'P-U SgNet answer span'],
#       dtype='object')
#                      Question_Id  \
# 0       56be85543aeaaa14008c9063
# 1       56be85543aeaaa14008c9063
# 2       56be85543aeaaa14008c9063
# 3       56be85543aeaaa14008c9065
# 4       56be85543aeaaa14008c9065
# ...                          ...
# 162180  5735d259012e2f140011a09f
# 162181  5735d259012e2f140011a09f
# 162182  5735d259012e2f140011a0a0
# 162183  5735d259012e2f140011a0a0
# 162184  5735d259012e2f140011a0a1
#
#                                                   Context  \
# 0       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# ...                                                   ...
# 162180  Kathmandu Metropolitan City (KMC), in order to...
# 162181  Kathmandu Metropolitan City (KMC), in order to...
# 162182  Kathmandu Metropolitan City (KMC), in order to...
# 162183  Kathmandu Metropolitan City (KMC), in order to...
# 162184  Kathmandu Metropolitan City (KMC), in order to...
#
#                                         Original_Question  \
# 0                When did Beyonce start becoming popular?
# 1                When did Beyonce start becoming popular?
# 2                When did Beyonce start becoming popular?
# 3       What areas did Beyonce compete in when she was...
# 4       What areas did Beyonce compete in when she was...
# ...                                                   ...
# 162180  With what Belorussian city does Kathmandu have...
# 162181  With what Belorussian city does Kathmandu have...
# 162182  In what year did Kathmandu create its initial ...
# 162183  In what year did Kathmandu create its initial ...
# 162184                      What is KMC an initialism of?
#
#                     Original_Answer  \
# 0                 in the late 1990s
# 1                 in the late 1990s
# 2                 in the late 1990s
# 3               singing and dancing
# 4               singing and dancing
# ...                             ...
# 162180                        Minsk
# 162181                        Minsk
# 162182                         1975
# 162183                         1975
# 162184  Kathmandu Metropolitan City
#
#                                         Modified_Question  \
# 0             When didn't Beyonce start becoming popular?
# 1            When did Beyonce not start becoming popular?
# 2            When did Beyonce start not becoming popular?
# 3       What areas didn't Beyonce compete in when she ...
# 4       What areas did Beyonce compete in when she was...
# ...                                                   ...
# 162180  With what Belorussian city doesn't Kathmandu h...
# 162181  With what Belorussian city does Kathmandu not ...
# 162182  In what year didn't Kathmandu create its initi...
# 162183  In what year did Kathmandu not create its init...
# 162184                   What isn't KMC an initialism of?
#
#              O-Q model2 answer span  O-Q model2 start  O-Q model2 end  \
# 0                        late 1990s               275             286
# 1                        late 1990s               275             286
# 2                        late 1990s               275             286
# 3               singing and dancing               206             226
# 4               singing and dancing               206             226
# ...                             ...               ...             ...
# 162180                        Minsk               475             481
# 162181                        Minsk               475             481
# 162182                         1975               198             203
# 162183                         1975               198             203
# 162184  Kathmandu Metropolitan City                 0              27
#
#         O-Q model2 score O-Q model4 answer span  ...  \
# 0               0.636688             late 1990s  ...
# 1               0.636688             late 1990s  ...
# 2               0.636688             late 1990s  ...
# 3               0.836062    singing and dancing  ...
# 4               0.836062    singing and dancing  ...
# ...                  ...                    ...  ...
# 162180          0.972188                  Minsk  ...
# 162181          0.972188                  Minsk  ...
# 162182          0.996814                   1975  ...
# 162183          0.996814                   1975  ...
# 162184          0.949815              Kathmandu  ...
#
#                                   P-U electra answer span  P-U electra start  \
# 0       hiatus saw the release of Beyoncé's debut albu...                456
# 1       release of Beyoncé's debut album, Dangerously ...                471
# 2                                                    2003                526
# 3                                                 dancing                219
# 4                                     singing and dancing                207
# ...                                                   ...                ...
# 162180                                              Minsk                476
# 162181                                              Minsk                476
# 162182                                               1975                199
# 162183                                               1975                199
# 162184                                                IRC                135
#
#         P-U electra end P-U electra score           P-U roberta answer span  \
# 0                   524      3.663901e-12                                 4
# 1                   530      3.835370e-11                                 4
# 2                   530      5.543973e-05                              2003
# 3                   226      7.576573e-12    Beyoncé Giselle Knowles-Carter
# 4                   226      2.723598e-07  singing and dancing competitions
# ...                 ...               ...                               ...
# 162180              481      3.207862e-09                             Minsk
# 162181              481      1.300888e-08                             Minsk
# 162182              203      3.486395e-12                              1975
# 162183              203      9.288781e-13                              1975
# 162184              138      3.328238e-14           Motsumoto City of Japan
#
#         P-U roberta start  P-U roberta end P-U roberta score  \
# 0                      74               75      2.375909e-09
# 1                      74               75      1.432447e-09
# 2                     526              530      2.668854e-09
# 3                       0               30      2.841676e-09
# 4                     207              239      1.565185e-06
# ...                   ...              ...               ...
# 162180                476              481      5.784440e-09
# 162181                476              481      1.215596e-07
# 162182                199              203      8.635733e-11
# 162183                199              203      1.607741e-10
# 162184                350              373      5.829913e-11
#
#                                     P-U retro answer span  \
# 0       <No Answer>. The question is not answerable ac...
# 1       <No Answer>. The question is not answerable ac...
# 2       <No Answer>. The question is not answerable ac...
# 3       <No Answer>. The question is not answerable ac...
# 4       <No Answer>. The question is not answerable ac...
# ...                                                   ...
# 162180  <No Answer>. The question is not answerable ac...
# 162181  <No Answer>. The question is not answerable ac...
# 162182  <No Answer>. The question is not answerable ac...
# 162183  <No Answer>. The question is not answerable ac...
# 162184  <No Answer>. The question is not answerable ac...
#
#         P-U SgNet answer span
# 0           the late 1990s as
# 1           the late 1990s as
# 2           the late 1990s as
# 3                         NaN
# 4                         NaN
# ...                       ...
# 162180                    NaN
# 162181                    NaN
# 162182                    NaN
# 162183                    NaN
# 162184                  empty
#
# [162185 rows x 41 columns]

# %% [markdown]
# # Cleaning Model's answer

# %%
import re

def preprocess_text2(text):
    if not pd.isna(text): 
        # Remove special characters from the left side
        text = re.sub(r'^\W+', '', text)

        # Remove special characters from the right side
        text = re.sub(r'\W+$', '', text)
        return text
    else: ## it's nan
        return ''
    
    
def preprocess_text(text):
    if not pd.isna(text): 
        return text
    else: ## it's nan
        return ''

text = "(2003)!,"
processed_text = preprocess_text(text)
print(processed_text)
# Out:
# (2003)!,

# %%
### Cleaning the result of models
import ast
Cln_orgQ_model2 = []
Cln_orgQ_model4 = []
Cln_orgQ_electra = []
Cln_orgQ_roberta = []
Cln_orgQ_sgnet = []
Cln_orgQ_retro = []

Cln_potUQ_model2 = []
Cln_potUQ_model4 = []
Cln_potUQ_electra = []
Cln_potUQ_roberta = []
Cln_potUQ_sgnet = []
Cln_potUQ_retro = []

for index, row in negation.iterrows():
    if index % 100000 == 0:
        print(index)
    
    original_question_model2 = row['O-Q model2 answer span']
    original_question_model4 = row['O-Q model4 answer span']
    original_question_electra = row['O-Q electra answer span']
    original_question_roberta = row['O-Q roberta answer span']
    original_question_sgnet = row['O-Q sgnet answer span']
    original_question_retro = row['O-Q retro answer span']
    
    potentialU_question_model2 = row['P-U model2 answer span']
    potentialU_question_model4 = row['P-U model4 answer span']
    potentialU_question_electra = row['P-U electra answer span']
    potentialU_question_roberta = row['P-U roberta answer span']
    potentialU_question_sgnet = row['P-U SgNet answer span']
    potentialU_question_retro = row['P-U retro answer span']
    
    
    Cln_orgQ_model2.append(preprocess_text(original_question_model2))
    Cln_orgQ_model4.append(preprocess_text(original_question_model4))
    Cln_orgQ_electra.append(preprocess_text(original_question_electra))
    Cln_orgQ_roberta.append(preprocess_text(original_question_roberta))
    Cln_orgQ_sgnet.append(preprocess_text(original_question_sgnet))
    Cln_orgQ_retro.append(preprocess_text(original_question_retro))
    
    Cln_potUQ_model2.append(preprocess_text(potentialU_question_model2))
    Cln_potUQ_model4.append(preprocess_text(potentialU_question_model4))
    Cln_potUQ_electra.append(preprocess_text(potentialU_question_electra))
    Cln_potUQ_roberta.append(preprocess_text(potentialU_question_roberta))
    Cln_potUQ_sgnet.append(preprocess_text(potentialU_question_sgnet))
    Cln_potUQ_retro.append(preprocess_text(potentialU_question_retro))

    
      
negation['Cln_orgQ_model2'] = Cln_orgQ_model2
negation['Cln_orgQ_model4'] = Cln_orgQ_model4
negation['Cln_orgQ_electra'] = Cln_orgQ_electra
negation['Cln_orgQ_roberta'] = Cln_orgQ_roberta
negation['Cln_orgQ_sgnet'] = Cln_orgQ_sgnet
negation['Cln_orgQ_retro'] = Cln_orgQ_retro


negation['Cln_potUQ_model2'] = Cln_potUQ_model2
negation['Cln_potUQ_model4'] = Cln_potUQ_model4
negation['Cln_potUQ_electra'] = Cln_potUQ_electra
negation['Cln_potUQ_roberta'] = Cln_potUQ_roberta
negation['Cln_potUQ_sgnet'] = Cln_potUQ_sgnet
negation['Cln_potUQ_retro'] = Cln_potUQ_retro

# Specify the desired column order
new_column_order = [
    'Question_Id', 'Context', 'Original_Question', 'Original_Answer',
       'Modified_Question', 'O-Q model2 answer span', 'Cln_orgQ_model2',
       'O-Q model2 start', 'O-Q model2 end', 'O-Q model2 score',
       'O-Q model4 answer span', 'Cln_orgQ_model4', 'O-Q model4 start', 'O-Q model4 end',
       'O-Q model4 score', 'O-Q electra answer span','Cln_orgQ_electra', 'O-Q electra start',
       'O-Q electra end', 'O-Q electra score', 'O-Q roberta answer span', 'Cln_orgQ_roberta',
       'O-Q roberta start', 'O-Q roberta end', 'O-Q roberta score',
       'O-Q sgnet answer span', 'Cln_orgQ_sgnet' ,'O-Q retro answer span', 'Cln_orgQ_retro',
       'P-U model2 answer span', 'Cln_potUQ_model2', 'P-U model2 start', 'P-U model2 end',
       'P-U model2 score', 'P-U model4 answer span', 'Cln_potUQ_model4', 'P-U model4 start',
       'P-U model4 end', 'P-U model4 score', 'P-U electra answer span', 'Cln_potUQ_electra',
       'P-U electra start', 'P-U electra end', 'P-U electra score',
       'P-U roberta answer span', 'Cln_potUQ_roberta', 'P-U roberta start', 'P-U roberta end',
       'P-U roberta score', 'P-U SgNet answer span', 'Cln_potUQ_sgnet', 'P-U retro answer span', 'Cln_potUQ_retro'
    
]



       
# Reorder the columns in the DataFrame
negation = negation[new_column_order]


negation
# Out:
# 0
# 100000
#                      Question_Id  \
# 0       56be85543aeaaa14008c9063
# 1       56be85543aeaaa14008c9063
# 2       56be85543aeaaa14008c9063
# 3       56be85543aeaaa14008c9065
# 4       56be85543aeaaa14008c9065
# ...                          ...
# 162180  5735d259012e2f140011a09f
# 162181  5735d259012e2f140011a09f
# 162182  5735d259012e2f140011a0a0
# 162183  5735d259012e2f140011a0a0
# 162184  5735d259012e2f140011a0a1
#
#                                                   Context  \
# 0       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# ...                                                   ...
# 162180  Kathmandu Metropolitan City (KMC), in order to...
# 162181  Kathmandu Metropolitan City (KMC), in order to...
# 162182  Kathmandu Metropolitan City (KMC), in order to...
# 162183  Kathmandu Metropolitan City (KMC), in order to...
# 162184  Kathmandu Metropolitan City (KMC), in order to...
#
#                                         Original_Question  \
# 0                When did Beyonce start becoming popular?
# 1                When did Beyonce start becoming popular?
# 2                When did Beyonce start becoming popular?
# 3       What areas did Beyonce compete in when she was...
# 4       What areas did Beyonce compete in when she was...
# ...                                                   ...
# 162180  With what Belorussian city does Kathmandu have...
# 162181  With what Belorussian city does Kathmandu have...
# 162182  In what year did Kathmandu create its initial ...
# 162183  In what year did Kathmandu create its initial ...
# 162184                      What is KMC an initialism of?
#
#                     Original_Answer  \
# 0                 in the late 1990s
# 1                 in the late 1990s
# 2                 in the late 1990s
# 3               singing and dancing
# 4               singing and dancing
# ...                             ...
# 162180                        Minsk
# 162181                        Minsk
# 162182                         1975
# 162183                         1975
# 162184  Kathmandu Metropolitan City
#
#                                         Modified_Question  \
# 0             When didn't Beyonce start becoming popular?
# 1            When did Beyonce not start becoming popular?
# 2            When did Beyonce start not becoming popular?
# 3       What areas didn't Beyonce compete in when she ...
# 4       What areas did Beyonce compete in when she was...
# ...                                                   ...
# 162180  With what Belorussian city doesn't Kathmandu h...
# 162181  With what Belorussian city does Kathmandu not ...
# 162182  In what year didn't Kathmandu create its initi...
# 162183  In what year did Kathmandu not create its init...
# 162184                   What isn't KMC an initialism of?
#
#              O-Q model2 answer span              Cln_orgQ_model2  \
# 0                        late 1990s                   late 1990s
# 1                        late 1990s                   late 1990s
# 2                        late 1990s                   late 1990s
# 3               singing and dancing          singing and dancing
# 4               singing and dancing          singing and dancing
# ...                             ...                          ...
# 162180                        Minsk                        Minsk
# 162181                        Minsk                        Minsk
# 162182                         1975                         1975
# 162183                         1975                         1975
# 162184  Kathmandu Metropolitan City  Kathmandu Metropolitan City
#
#         O-Q model2 start  O-Q model2 end  O-Q model2 score  ...  \
# 0                    275             286          0.636688  ...
# 1                    275             286          0.636688  ...
# 2                    275             286          0.636688  ...
# 3                    206             226          0.836062  ...
# 4                    206             226          0.836062  ...
# ...                  ...             ...               ...  ...
# 162180               475             481          0.972188  ...
# 162181               475             481          0.972188  ...
# 162182               198             203          0.996814  ...
# 162183               198             203          0.996814  ...
# 162184                 0              27          0.949815  ...
#
#        P-U electra score           P-U roberta answer span  \
# 0           3.663901e-12                                 4
# 1           3.835370e-11                                 4
# 2           5.543973e-05                              2003
# 3           7.576573e-12    Beyoncé Giselle Knowles-Carter
# 4           2.723598e-07  singing and dancing competitions
# ...                  ...                               ...
# 162180      3.207862e-09                             Minsk
# 162181      1.300888e-08                             Minsk
# 162182      3.486395e-12                              1975
# 162183      9.288781e-13                              1975
# 162184      3.328238e-14           Motsumoto City of Japan
#
#                        Cln_potUQ_roberta  P-U roberta start  P-U roberta end  \
# 0                                      4                 74               75
# 1                                      4                 74               75
# 2                                   2003                526              530
# 3         Beyoncé Giselle Knowles-Carter                  0               30
# 4       singing and dancing competitions                207              239
# ...                                  ...                ...              ...
# 162180                             Minsk                476              481
# 162181                             Minsk                476              481
# 162182                              1975                199              203
# 162183                              1975                199              203
# 162184           Motsumoto City of Japan                350              373
#
#        P-U roberta score P-U SgNet answer span    Cln_potUQ_sgnet  \
# 0           2.375909e-09     the late 1990s as  the late 1990s as
# 1           1.432447e-09     the late 1990s as  the late 1990s as
# 2           2.668854e-09     the late 1990s as  the late 1990s as
# 3           2.841676e-09                   NaN
# 4           1.565185e-06                   NaN
# ...                  ...                   ...                ...
# 162180      5.784440e-09                   NaN
# 162181      1.215596e-07                   NaN
# 162182      8.635733e-11                   NaN
# 162183      1.607741e-10                   NaN
# 162184      5.829913e-11                 empty              empty
#
#                                     P-U retro answer span  \
# 0       <No Answer>. The question is not answerable ac...
# 1       <No Answer>. The question is not answerable ac...
# 2       <No Answer>. The question is not answerable ac...
# 3       <No Answer>. The question is not answerable ac...
# 4       <No Answer>. The question is not answerable ac...
# ...                                                   ...
# 162180  <No Answer>. The question is not answerable ac...
# 162181  <No Answer>. The question is not answerable ac...
# 162182  <No Answer>. The question is not answerable ac...
# 162183  <No Answer>. The question is not answerable ac...
# 162184  <No Answer>. The question is not answerable ac...
#
#                                           Cln_potUQ_retro
# 0       <No Answer>. The question is not answerable ac...
# 1       <No Answer>. The question is not answerable ac...
# 2       <No Answer>. The question is not answerable ac...
# 3       <No Answer>. The question is not answerable ac...
# 4       <No Answer>. The question is not answerable ac...
# ...                                                   ...
# 162180  <No Answer>. The question is not answerable ac...
# 162181  <No Answer>. The question is not answerable ac...
# 162182  <No Answer>. The question is not answerable ac...
# 162183  <No Answer>. The question is not answerable ac...
# 162184  <No Answer>. The question is not answerable ac...
#
# [162185 rows x 53 columns]

# %% [markdown]
#  # EM and unanswerability

# %%
EM_dataset_Cln_orgQ_model2 = []
EM_dataset_Cln_orgQ_model4 = []
EM_dataset_Cln_orgQ_electra = []
EM_dataset_Cln_orgQ_roberta = []
EM_dataset_Cln_orgQ_sgnet = []
EM_dataset_Cln_orgQ_retro = []

EM_dataset_Cln_potUQ_model2 = []
EM_dataset_Cln_potUQ_model4 = []
EM_dataset_Cln_potUQ_electra = []
EM_dataset_Cln_potUQ_roberta = []
Null_EM_dataset_Cln_potUQ_sgnet = []
Null_EM_dataset_Cln_potUQ_retro = []
### for unanswerability
un_potUQ_model2 = []
un_potUQ_model4 = []
un_potUQ_electra = []
un_potUQ_roberta = []
un_potUQ_sgnet = []
un_potUQ_retro = []


for index, row in negation.iterrows():
    if index % 100000 == 0:
        print(index)
        
    original_answer_in_dataset = row['Original_Answer']

    original_question_model2 = row['Cln_orgQ_model2']
    original_question_model4 = row['Cln_orgQ_model4']
    original_question_electra = row['Cln_orgQ_electra']
    original_question_roberta = row['Cln_orgQ_roberta']
    original_question_sgnet = row['Cln_orgQ_sgnet']
    original_question_retro = row['Cln_orgQ_retro']
    

    potentialU_question_sgnet = row['Cln_potUQ_sgnet']
    potentialU_question_retro = row['Cln_potUQ_retro']
    potentialU_questionS_model2 = row['P-U model2 score']
    potentialU_questionS_model4 = row['P-U model4 score']
    potentialU_questionS_electra = row['P-U electra score']
    potentialU_questionS_roberta = row['P-U roberta score']
    



    if original_answer_in_dataset == original_question_model2:  # EM checking (dataset , model on org_q)
        EM_dataset_Cln_orgQ_model2.append(1)
    else:
        EM_dataset_Cln_orgQ_model2.append(0)
    
    if original_answer_in_dataset == original_question_model4:
        EM_dataset_Cln_orgQ_model4.append(1)
    else:
        EM_dataset_Cln_orgQ_model4.append(0)
    
    if original_answer_in_dataset == original_question_electra:
        EM_dataset_Cln_orgQ_electra.append(1)
    else:
        EM_dataset_Cln_orgQ_electra.append(0)
        
    if original_answer_in_dataset == original_question_roberta:
        EM_dataset_Cln_orgQ_roberta.append(1)
    else:
        EM_dataset_Cln_orgQ_roberta.append(0)
    
    if original_answer_in_dataset == original_question_sgnet:
        EM_dataset_Cln_orgQ_sgnet.append(1)
    else:
        EM_dataset_Cln_orgQ_sgnet.append(0)
        
    if original_answer_in_dataset == original_question_retro:
        EM_dataset_Cln_orgQ_retro.append(1)
    else:
        EM_dataset_Cln_orgQ_retro.append(0)
        
    if original_answer_in_dataset == potentialU_question_model2: ## EM checking (dataset, model on p-u_q)
        EM_dataset_Cln_potUQ_model2.append(1)
    else:
        EM_dataset_Cln_potUQ_model2.append(0)
    
    if original_answer_in_dataset == potentialU_question_model4:
        EM_dataset_Cln_potUQ_model4.append(1)
    else:
        EM_dataset_Cln_potUQ_model4.append(0)
    
    if original_answer_in_dataset == potentialU_question_electra:
        EM_dataset_Cln_potUQ_electra.append(1)
    else:
        EM_dataset_Cln_potUQ_electra.append(0)
        
    if original_answer_in_dataset == potentialU_question_roberta:
        EM_dataset_Cln_potUQ_roberta.append(1)
    else:
        EM_dataset_Cln_potUQ_roberta.append(0)
    
    Null_EM_dataset_Cln_potUQ_sgnet.append(100)
    Null_EM_dataset_Cln_potUQ_retro.append(100)

    if potentialU_questionS_model2 <= 0.096476303 : # unanswerablity checking
        un_potUQ_model2.append(0)  #unanswerable
    else:
        un_potUQ_model2.append(1)  #answerable
    
    if potentialU_questionS_model4 <= 0.15272566:
        un_potUQ_model4.append(0) #unanswerable
    else:
        un_potUQ_model4.append(1) #answerable
    
    if potentialU_questionS_electra <= 0.141489303:
        un_potUQ_electra.append(0) #unanswerable
    else:
        un_potUQ_electra.append(1) #answerable
        
    if potentialU_questionS_roberta <= 0.063691394:
        un_potUQ_roberta.append(0) #unanswerable
    else: 
        un_potUQ_roberta.append(1) #answerable
    
    if potentialU_question_sgnet == "": 
        un_potUQ_sgnet.append(0) #unanswerable
    else:
        un_potUQ_sgnet.append(1) #answerable
        
    if potentialU_question_retro == "" or potentialU_question_retro.startswith("[SEP]") or potentialU_question_retro == "'" or potentialU_question_retro == "," or potentialU_question_retro == "<No Answer>. The question is not answerable according to the context." or potentialU_question_retro == "<unk>=0" :
        un_potUQ_retro.append(0) #unanswerable
    else:
        un_potUQ_retro.append(1) #answerable
        
negation['EM dataset with clean orgQ_model2'] = EM_dataset_Cln_orgQ_model2
negation['EM dataset with clean orgQ_model4'] = EM_dataset_Cln_orgQ_model4
negation['EM dataset with clean orgQ_electra'] = EM_dataset_Cln_orgQ_electra
negation['EM dataset with clean orgQ_roberta'] = EM_dataset_Cln_orgQ_roberta
negation['EM dataset with clean orgQ_sgnet'] = EM_dataset_Cln_orgQ_sgnet
negation['EM dataset with clean orgQ_retro'] = EM_dataset_Cln_orgQ_retro


negation['EM dataset with clean potentailUQ_model2'] = EM_dataset_Cln_potUQ_model2
negation['EM dataset with clean potentailUQ_model4'] = EM_dataset_Cln_potUQ_model4
negation['EM dataset with clean potentailUQ_electra'] = EM_dataset_Cln_potUQ_electra
negation['EM dataset with clean potentailUQ_roberta'] = EM_dataset_Cln_potUQ_roberta
negation['NULL EM dataset with clean potentailUQ_sgnet'] = Null_EM_dataset_Cln_potUQ_sgnet
negation['NULL EM dataset with clean potentailUQ_retro'] = Null_EM_dataset_Cln_potUQ_retro


negation['unanswerability potentailUQ_model2'] = un_potUQ_model2
negation['unanswerability potentailUQ_model4'] = un_potUQ_model4
negation['unanswerability potentailUQ_electra'] = un_potUQ_electra
negation['unanswerability potentailUQ_roberta'] = un_potUQ_roberta
negation['unanswerability potentailUQ_sgnet'] = un_potUQ_sgnet
negation['unanswerability potentailUQ_retro'] = un_potUQ_retro

new_column_order = [
    'Question_Id', 'Context', 'Original_Question', 'Original_Answer',
    'Modified_Question', 'O-Q model2 answer span', 'Cln_orgQ_model2', 'EM dataset with clean orgQ_model2',
    'O-Q model2 start', 'O-Q model2 end', 'O-Q model2 score',
    'O-Q model4 answer span', 'Cln_orgQ_model4','EM dataset with clean orgQ_model4' ,'O-Q model4 start', 'O-Q model4 end',
    'O-Q model4 score', 'O-Q electra answer span','Cln_orgQ_electra', 'EM dataset with clean orgQ_electra', 'O-Q electra start',
    'O-Q electra end', 'O-Q electra score', 'O-Q roberta answer span', 'Cln_orgQ_roberta', 'EM dataset with clean orgQ_roberta',
    'O-Q roberta start', 'O-Q roberta end', 'O-Q roberta score',
    'O-Q sgnet answer span', 'Cln_orgQ_sgnet', 'EM dataset with clean orgQ_sgnet' ,'O-Q retro answer span', 'Cln_orgQ_retro', 'EM dataset with clean orgQ_retro',
    'P-U model2 answer span', 'Cln_potUQ_model2','EM dataset with clean potentailUQ_model2','unanswerability potentailUQ_model2' ,'P-U model2 start', 'P-U model2 end',
    'P-U model2 score', 'P-U model4 answer span', 'Cln_potUQ_model4','EM dataset with clean potentailUQ_model4','unanswerability potentailUQ_model4', 'P-U model4 start',
    'P-U model4 end', 'P-U model4 score', 'P-U electra answer span', 'Cln_potUQ_electra', 'EM dataset with clean potentailUQ_electra','unanswerability potentailUQ_electra',
    'P-U electra start', 'P-U electra end', 'P-U electra score',
    'P-U roberta answer span', 'Cln_potUQ_roberta','EM dataset with clean potentailUQ_roberta','unanswerability potentailUQ_roberta' ,'P-U roberta start', 'P-U roberta end',
    'P-U roberta score', 'P-U SgNet answer span', 'Cln_potUQ_sgnet','NULL EM dataset with clean potentailUQ_sgnet' ,'unanswerability potentailUQ_sgnet','P-U retro answer span', 'Cln_potUQ_retro',
    'NULL EM dataset with clean potentailUQ_retro', 'unanswerability potentailUQ_retro'
    
]



# Reorder the columns in the DataFrame
negation = negation[new_column_order]


negation
# Out:
# 0
# 100000
# /tmp/ipykernel_1622476/3247661948.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['EM dataset with clean orgQ_model2'] = EM_dataset_Cln_orgQ_model2
# /tmp/ipykernel_1622476/3247661948.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['EM dataset with clean orgQ_model4'] = EM_dataset_Cln_orgQ_model4
# /tmp/ipykernel_1622476/3247661948.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['EM dataset with clean orgQ_electra'] = EM_dataset_Cln_orgQ_electra
# /tmp/ipykernel_1622476/3247661948.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['EM dataset with clean orgQ_roberta'] = EM_dataset_Cln_orgQ_roberta
# /tmp/ipykernel_1622476/3247661948.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['EM dataset with clean orgQ_sgnet'] = EM_dataset_Cln_orgQ_sgnet
# /tmp/ipykernel_1622476/3247661948.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['EM dataset with clean orgQ_retro'] = EM_dataset_Cln_orgQ_retro
# /tmp/ipykernel_1622476/3247661948.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['EM dataset with clean potentailUQ_model2'] = EM_dataset_Cln_potUQ_model2
# /tmp/ipykernel_1622476/3247661948.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['EM dataset with clean potentailUQ_model4'] = EM_dataset_Cln_potUQ_model4
# /tmp/ipykernel_1622476/3247661948.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['EM dataset with clean potentailUQ_electra'] = EM_dataset_Cln_potUQ_electra
# /tmp/ipykernel_1622476/3247661948.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['EM dataset with clean potentailUQ_roberta'] = EM_dataset_Cln_potUQ_roberta
# /tmp/ipykernel_1622476/3247661948.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['NULL EM dataset with clean potentailUQ_sgnet'] = Null_EM_dataset_Cln_potUQ_sgnet
# /tmp/ipykernel_1622476/3247661948.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['NULL EM dataset with clean potentailUQ_retro'] = Null_EM_dataset_Cln_potUQ_retro
# /tmp/ipykernel_1622476/3247661948.py:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['unanswerability potentailUQ_model2'] = un_potUQ_model2
# /tmp/ipykernel_1622476/3247661948.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['unanswerability potentailUQ_model4'] = un_potUQ_model4
# /tmp/ipykernel_1622476/3247661948.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['unanswerability potentailUQ_electra'] = un_potUQ_electra
# /tmp/ipykernel_1622476/3247661948.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['unanswerability potentailUQ_roberta'] = un_potUQ_roberta
# /tmp/ipykernel_1622476/3247661948.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['unanswerability potentailUQ_sgnet'] = un_potUQ_sgnet
# /tmp/ipykernel_1622476/3247661948.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negation['unanswerability potentailUQ_retro'] = un_potUQ_retro
#                      Question_Id  \
# 0       56be85543aeaaa14008c9063
# 1       56be85543aeaaa14008c9063
# 2       56be85543aeaaa14008c9063
# 3       56be85543aeaaa14008c9065
# 4       56be85543aeaaa14008c9065
# ...                          ...
# 162180  5735d259012e2f140011a09f
# 162181  5735d259012e2f140011a09f
# 162182  5735d259012e2f140011a0a0
# 162183  5735d259012e2f140011a0a0
# 162184  5735d259012e2f140011a0a1
#
#                                                   Context  \
# 0       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# ...                                                   ...
# 162180  Kathmandu Metropolitan City (KMC), in order to...
# 162181  Kathmandu Metropolitan City (KMC), in order to...
# 162182  Kathmandu Metropolitan City (KMC), in order to...
# 162183  Kathmandu Metropolitan City (KMC), in order to...
# 162184  Kathmandu Metropolitan City (KMC), in order to...
#
#                                         Original_Question  \
# 0                When did Beyonce start becoming popular?
# 1                When did Beyonce start becoming popular?
# 2                When did Beyonce start becoming popular?
# 3       What areas did Beyonce compete in when she was...
# 4       What areas did Beyonce compete in when she was...
# ...                                                   ...
# 162180  With what Belorussian city does Kathmandu have...
# 162181  With what Belorussian city does Kathmandu have...
# 162182  In what year did Kathmandu create its initial ...
# 162183  In what year did Kathmandu create its initial ...
# 162184                      What is KMC an initialism of?
#
#                     Original_Answer  \
# 0                 in the late 1990s
# 1                 in the late 1990s
# 2                 in the late 1990s
# 3               singing and dancing
# 4               singing and dancing
# ...                             ...
# 162180                        Minsk
# 162181                        Minsk
# 162182                         1975
# 162183                         1975
# 162184  Kathmandu Metropolitan City
#
#                                         Modified_Question  \
# 0             When didn't Beyonce start becoming popular?
# 1            When did Beyonce not start becoming popular?
# 2            When did Beyonce start not becoming popular?
# 3       What areas didn't Beyonce compete in when she ...
# 4       What areas did Beyonce compete in when she was...
# ...                                                   ...
# 162180  With what Belorussian city doesn't Kathmandu h...
# 162181  With what Belorussian city does Kathmandu not ...
# 162182  In what year didn't Kathmandu create its initi...
# 162183  In what year did Kathmandu not create its init...
# 162184                   What isn't KMC an initialism of?
#
#              O-Q model2 answer span              Cln_orgQ_model2  \
# 0                        late 1990s                   late 1990s
# 1                        late 1990s                   late 1990s
# 2                        late 1990s                   late 1990s
# 3               singing and dancing          singing and dancing
# 4               singing and dancing          singing and dancing
# ...                             ...                          ...
# 162180                        Minsk                        Minsk
# 162181                        Minsk                        Minsk
# 162182                         1975                         1975
# 162183                         1975                         1975
# 162184  Kathmandu Metropolitan City  Kathmandu Metropolitan City
#
#         EM dataset with clean orgQ_model2  O-Q model2 start  O-Q model2 end  \
# 0                                       0               275             286
# 1                                       0               275             286
# 2                                       0               275             286
# 3                                       0               206             226
# 4                                       0               206             226
# ...                                   ...               ...             ...
# 162180                                  0               475             481
# 162181                                  0               475             481
# 162182                                  1               198             203
# 162183                                  1               198             203
# 162184                                  1                 0              27
#
#         ...  P-U roberta end P-U roberta score P-U SgNet answer span  \
# 0       ...               75      2.375909e-09     the late 1990s as
# 1       ...               75      1.432447e-09     the late 1990s as
# 2       ...              530      2.668854e-09     the late 1990s as
# 3       ...               30      2.841676e-09                   NaN
# 4       ...              239      1.565185e-06                   NaN
# ...     ...              ...               ...                   ...
# 162180  ...              481      5.784440e-09                   NaN
# 162181  ...              481      1.215596e-07                   NaN
# 162182  ...              203      8.635733e-11                   NaN
# 162183  ...              203      1.607741e-10                   NaN
# 162184  ...              373      5.829913e-11                 empty
#
#           Cln_potUQ_sgnet  NULL EM dataset with clean potentailUQ_sgnet  \
# 0       the late 1990s as                                           100
# 1       the late 1990s as                                           100
# 2       the late 1990s as                                           100
# 3                                                                   100
# 4                                                                   100
# ...                   ...                                           ...
# 162180                                                              100
# 162181                                                              100
# 162182                                                              100
# 162183                                                              100
# 162184              empty                                           100
#
#         unanswerability potentailUQ_sgnet  \
# 0                                       1
# 1                                       1
# 2                                       1
# 3                                       0
# 4                                       0
# ...                                   ...
# 162180                                  0
# 162181                                  0
# 162182                                  0
# 162183                                  0
# 162184                                  1
#
#                                     P-U retro answer span  \
# 0       <No Answer>. The question is not answerable ac...
# 1       <No Answer>. The question is not answerable ac...
# 2       <No Answer>. The question is not answerable ac...
# 3       <No Answer>. The question is not answerable ac...
# 4       <No Answer>. The question is not answerable ac...
# ...                                                   ...
# 162180  <No Answer>. The question is not answerable ac...
# 162181  <No Answer>. The question is not answerable ac...
# 162182  <No Answer>. The question is not answerable ac...
# 162183  <No Answer>. The question is not answerable ac...
# 162184  <No Answer>. The question is not answerable ac...
#
#                                           Cln_potUQ_retro  \
# 0       <No Answer>. The question is not answerable ac...
# 1       <No Answer>. The question is not answerable ac...
# 2       <No Answer>. The question is not answerable ac...
# 3       <No Answer>. The question is not answerable ac...
# 4       <No Answer>. The question is not answerable ac...
# ...                                                   ...
# 162180  <No Answer>. The question is not answerable ac...
# 162181  <No Answer>. The question is not answerable ac...
# 162182  <No Answer>. The question is not answerable ac...
# 162183  <No Answer>. The question is not answerable ac...
# 162184  <No Answer>. The question is not answerable ac...
#
#        NULL EM dataset with clean potentailUQ_retro  \
# 0                                               100
# 1                                               100
# 2                                               100
# 3                                               100
# 4                                               100
# ...                                             ...
# 162180                                          100
# 162181                                          100
# 162182                                          100
# 162183                                          100
# 162184                                          100
#
#         unanswerability potentailUQ_retro
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 162180                                  0
# 162181                                  0
# 162182                                  0
# 162183                                  0
# 162184                                  0
#
# [162185 rows x 71 columns]

# %% [markdown]
# # Working on EM results

# %%
import pandas as pd
from tqdm import tqdm

# Define an empty list to hold the rows
rows = []

# Iterate through the DataFrame using iterrows
for index, row in tqdm(negation.iterrows(), total=negation.shape[0], desc="Processing rows"):
    if index % 100000 == 0: 
        print(index)

    qid = row['Question_Id']
    context = row['Context']
    org_question = row['Original_Question']
    org_answer = row['Original_Answer']
    pu_question = row['Modified_Question']

    model_data = [
        ('model 2', row['Cln_orgQ_model2'], row['Cln_potUQ_model2'], row['EM dataset with clean orgQ_model2'], row['EM dataset with clean potentailUQ_model2'],row['unanswerability potentailUQ_model2']),
        ('model 4', row['Cln_orgQ_model4'], row['Cln_potUQ_model4'], row['EM dataset with clean orgQ_model4'], row['EM dataset with clean potentailUQ_model4'],row['unanswerability potentailUQ_model4']),
        ('electra', row['Cln_orgQ_electra'], row['Cln_potUQ_electra'], row['EM dataset with clean orgQ_electra'], row['EM dataset with clean potentailUQ_electra'],row['unanswerability potentailUQ_electra']),
        ('roberta', row['Cln_orgQ_roberta'], row['Cln_potUQ_roberta'], row['EM dataset with clean orgQ_roberta'], row['EM dataset with clean potentailUQ_roberta'],row['unanswerability potentailUQ_roberta']),
        ('sgnet', row['Cln_orgQ_sgnet'], row['Cln_potUQ_sgnet'], row['EM dataset with clean orgQ_sgnet'], row['NULL EM dataset with clean potentailUQ_sgnet'],row['unanswerability potentailUQ_sgnet']),
        ('retro', row['Cln_orgQ_retro'], row['Cln_potUQ_retro'], row['EM dataset with clean orgQ_retro'], row['NULL EM dataset with clean potentailUQ_retro'],row['unanswerability potentailUQ_retro'])
    ]

    for model_name, org_output, pu_output, org_em, pu_em,un in model_data:
        row_data = [qid, context, org_question, org_answer, org_output, pu_question, pu_output, org_em, pu_em,un, model_name]
        rows.append(row_data)

# Convert the list of rows to a DataFrame
result_df = pd.DataFrame(rows, columns=['qid', 'context', 'original question in dataset', 'original answer span in dataset', 
                                        'output of model for original question', 'potentail_UQ question', 
                                        'output of model for potentail_UQ question', 
                                        'EM-dataset answer with model on orgQ', 'EM-dataset answer with model on potentialUQ', 'unanswerability on potential question',
                                        'model name'])

result_df
# Out:
# Processing rows:   2%|▉                                                         | 2790/162185 [00:00<00:20, 7961.00it/s]
# 0
# Processing rows:  63%|██████████████████████████████████▊                    | 102621/162185 [00:08<00:04, 12388.06it/s]
# 100000
# Processing rows: 100%|███████████████████████████████████████████████████████| 162185/162185 [00:12<00:00, 12497.00it/s]
#                              qid  \
# 0       56be85543aeaaa14008c9063
# 1       56be85543aeaaa14008c9063
# 2       56be85543aeaaa14008c9063
# 3       56be85543aeaaa14008c9063
# 4       56be85543aeaaa14008c9063
# ...                          ...
# 973105  5735d259012e2f140011a0a1
# 973106  5735d259012e2f140011a0a1
# 973107  5735d259012e2f140011a0a1
# 973108  5735d259012e2f140011a0a1
# 973109  5735d259012e2f140011a0a1
#
#                                                   context  \
# 0       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# ...                                                   ...
# 973105  Kathmandu Metropolitan City (KMC), in order to...
# 973106  Kathmandu Metropolitan City (KMC), in order to...
# 973107  Kathmandu Metropolitan City (KMC), in order to...
# 973108  Kathmandu Metropolitan City (KMC), in order to...
# 973109  Kathmandu Metropolitan City (KMC), in order to...
#
#                     original question in dataset  \
# 0       When did Beyonce start becoming popular?
# 1       When did Beyonce start becoming popular?
# 2       When did Beyonce start becoming popular?
# 3       When did Beyonce start becoming popular?
# 4       When did Beyonce start becoming popular?
# ...                                          ...
# 973105             What is KMC an initialism of?
# 973106             What is KMC an initialism of?
# 973107             What is KMC an initialism of?
# 973108             What is KMC an initialism of?
# 973109             What is KMC an initialism of?
#
#        original answer span in dataset output of model for original question  \
# 0                    in the late 1990s                            late 1990s
# 1                    in the late 1990s                            late 1990s
# 2                    in the late 1990s                     in the late 1990s
# 3                    in the late 1990s                            late 1990s
# 4                    in the late 1990s                                    in
# ...                                ...                                   ...
# 973105     Kathmandu Metropolitan City                             Kathmandu
# 973106     Kathmandu Metropolitan City                           Secretariat
# 973107     Kathmandu Metropolitan City           Kathmandu Metropolitan City
# 973108     Kathmandu Metropolitan City
# 973109     Kathmandu Metropolitan City           kathmandu metropolitan city
#
#                               potentail_UQ question  \
# 0       When didn't Beyonce start becoming popular?
# 1       When didn't Beyonce start becoming popular?
# 2       When didn't Beyonce start becoming popular?
# 3       When didn't Beyonce start becoming popular?
# 4       When didn't Beyonce start becoming popular?
# ...                                             ...
# 973105             What isn't KMC an initialism of?
# 973106             What isn't KMC an initialism of?
# 973107             What isn't KMC an initialism of?
# 973108             What isn't KMC an initialism of?
# 973109             What isn't KMC an initialism of?
#
#                 output of model for potentail_UQ question  \
# 0                                                 (2003),
# 1                                                    1990
# 2       hiatus saw the release of Beyoncé's debut albu...
# 3                                                       4
# 4                                       the late 1990s as
# ...                                                   ...
# 973105                                         Kathmandu.
# 973106                                                IRC
# 973107                            Motsumoto City of Japan
# 973108                                              empty
# 973109  <No Answer>. The question is not answerable ac...
#
#         EM-dataset answer with model on orgQ  \
# 0                                          0
# 1                                          0
# 2                                          1
# 3                                          0
# 4                                          0
# ...                                      ...
# 973105                                     0
# 973106                                     0
# 973107                                     1
# 973108                                     0
# 973109                                     0
#
#         EM-dataset answer with model on potentialUQ  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                               100
# ...                                             ...
# 973105                                            0
# 973106                                            0
# 973107                                            0
# 973108                                          100
# 973109                                          100
#
#         unanswerability on potential question model name
# 0                                           0    model 2
# 1                                           0    model 4
# 2                                           0    electra
# 3                                           0    roberta
# 4                                           1      sgnet
# ...                                       ...        ...
# 973105                                      0    model 4
# 973106                                      0    electra
# 973107                                      0    roberta
# 973108                                      1      sgnet
# 973109                                      0      retro
#
# [973110 rows x 11 columns]

# %%
result_df.to_csv('20240704-forAllConditions_Negation_Eval100.csv')
# result_df = pd.read_csv("20240624-forAllConditions_Negation_NEW-EVAL.csv",sep=',')
# modified_Entity_Swap_df
print('percentages over all models')
model_name_counts = result_df['model name'].value_counts()
print(model_name_counts)
print("total row = " , len(result_df['model name']))
# Out:
# percentages over all models
# model name
# model 2    162185
# model 4    162185
# electra    162185
# roberta    162185
# sgnet      162185
# retro      162185
# Name: count, dtype: int64
# total row =  973110

# %%
import pandas as pd

# Group by 'qid' and 'potential_UQ question'
grouped = result_df.groupby(['qid', 'potentail_UQ question'])

# Initialize an empty list to hold the result
result_list = []

# Iterate over each group
for name, group in grouped:
    model_name_list = []
    sw = True
    qid, potential_UQ_question = name  # unpack the group name
    
    # Assume that context, original_question, and original_answer_span are the same for each group
    context = group.iloc[0]['context']
    original_question = group.iloc[0]['original question in dataset']
    original_answer_span = group.iloc[0]['original answer span in dataset']
    
    # Iterate through each row in the group
    for index, row in group.iterrows():
        EM_orgQ = row['EM-dataset answer with model on orgQ']
        EM_modifiedQ = row['EM-dataset answer with model on potentialUQ']
        unanswerability = row['unanswerability on potential question']
        
        #### New eval (1,0,0) for model2,model4,electra,roberta AND (1,0) for retro and sgnet   
        model_n = row['model name']
        if EM_orgQ ==1 : ### originalQ should be answered
            if model_n == 'model 2' or model_n == 'model 4' or model_n == 'electra' or model_n == 'roberta': 
                if EM_modifiedQ == 0 and unanswerability == 0:  ## if model couldn't answer it (low score , and em=0 for p-u), now let's consider this model
                    if row['model name'] not in model_name_list:
                        model_name_list.append(row['model name'])
            elif model_n == 'retro' or model_n == 'sgnet':
                if unanswerability == 0:  ## if model couldn't answer it (null or empty answer), now let's consider this model
                    if row['model name'] not in model_name_list:
                        model_name_list.append(row['model name'])
    
    # Add the result to the list
    result_list.append({
        'qid': qid,
        'context': context,
        'original_question': original_question,
        'original_answer_span': original_answer_span,
        'potential_UQ_question': potential_UQ_question,
        'model_name_list': model_name_list,
        'len': len(model_name_list)
    })

# Create a new DataFrame from the result list
new_df = pd.DataFrame(result_list)
new_df.to_csv('20240704-for10Conditions_Negation_EVAL100.csv')
# Display the new DataFrame
display(new_df)
# Out:
#                              qid  \
# 0       56be85543aeaaa14008c9063
# 1       56be85543aeaaa14008c9063
# 2       56be85543aeaaa14008c9063
# 3       56be85543aeaaa14008c9065
# 4       56be85543aeaaa14008c9065
# ...                          ...
# 161162  573636bf9c79961900ff7e08
# 161163  573636bf9c79961900ff7e09
# 161164  573636bf9c79961900ff7e0a
# 161165  573636bf9c79961900ff7e0a
# 161166  573636bf9c79961900ff7e0a
#
#                                                   context  \
# 0       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# ...                                                   ...
# 161162  In contrast, Botswana has recently been forced...
# 161163  In contrast, Botswana has recently been forced...
# 161164  In contrast, Botswana has recently been forced...
# 161165  In contrast, Botswana has recently been forced...
# 161166  In contrast, Botswana has recently been forced...
#
#                                         original_question  \
# 0                When did Beyonce start becoming popular?
# 1                When did Beyonce start becoming popular?
# 2                When did Beyonce start becoming popular?
# 3       What areas did Beyonce compete in when she was...
# 4       What areas did Beyonce compete in when she was...
# ...                                                   ...
# 161162    What animal numbers have increased in Botswana?
# 161163     What animal numbers remain stable in Botswana?
# 161164  What else is partly to blame for the declining...
# 161165  What else is partly to blame for the declining...
# 161166  What else is partly to blame for the declining...
#
#        original_answer_span  \
# 0         in the late 1990s
# 1         in the late 1990s
# 2         in the late 1990s
# 3       singing and dancing
# 4       singing and dancing
# ...                     ...
# 161162         hippopotamus
# 161163             elephant
# 161164             poaching
# 161165             poaching
# 161166             poaching
#
#                                     potential_UQ_question  \
# 0            When did Beyonce not start becoming popular?
# 1            When did Beyonce start not becoming popular?
# 2             When didn't Beyonce start becoming popular?
# 3       What areas did Beyonce compete in when she was...
# 4       What areas did Beyonce compete in when she was...
# ...                                                   ...
# 161162  What animal numbers have not increased in Bots...
# 161163  What animal numbers remain not stable in Botsw...
# 161164  What else is partly to blame for the not decli...
# 161165  What else is partly to not blame for the decli...
# 161166  What else isn't partly to blame for the declin...
#
#                   model_name_list  len
# 0                       [electra]    1
# 1                       [electra]    1
# 2                       [electra]    1
# 3                [roberta, retro]    2
# 4       [electra, roberta, retro]    3
# ...                           ...  ...
# 161162  [model 4, roberta, retro]    3
# 161163  [electra, roberta, retro]    3
# 161164                  [electra]    1
# 161165                  [electra]    1
# 161166                  [electra]    1
#
# [161167 rows x 7 columns]

# %%
filtered_df = new_df[new_df['len'] >= 4]
filtered_df.to_csv('20240704-Negation-FinalUQ-EVAL100.csv')
filtered_df
# Out:
#                              qid  \
# 5       56be85543aeaaa14008c9065
# 9       56be86cf3aeaaa14008c9076
# 13      56be86cf3aeaaa14008c9079
# 16      56be88473aeaaa14008c9083
# 19      56be892d3aeaaa14008c908c
# ...                          ...
# 161151  5736357e506b471400236597
# 161157  5736357e506b47140023659a
# 161158  573636bf9c79961900ff7e06
# 161159  573636bf9c79961900ff7e06
# 161160  573636bf9c79961900ff7e06
#
#                                                   context  \
# 5       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 9       Following the disbandment of Destiny's Child i...
# 13      Following the disbandment of Destiny's Child i...
# 16      A self-described "modern-day feminist", Beyonc...
# 19      Beyoncé Giselle Knowles was born in Houston, T...
# ...                                                   ...
# 161151  The American bison is a large bovid which inha...
# 161157  The American bison is a large bovid which inha...
# 161158  In contrast, Botswana has recently been forced...
# 161159  In contrast, Botswana has recently been forced...
# 161160  In contrast, Botswana has recently been forced...
#
#                                         original_question  \
# 5       What areas did Beyonce compete in when she was...
# 9       After her second solo album, what other entert...
# 13      To set the record for Grammys, how many did Be...
# 16      Time magazine named her one of the most 100 wh...
# 19                   Where did Beyonce get her name from?
# ...                                                   ...
# 161151     What part of North America did the bison live?
# 161157                        What do bison still remain?
# 161158           What Botswana was resently forced to do?
# 161159           What Botswana was resently forced to do?
# 161160           What Botswana was resently forced to do?
#
#             original_answer_span  \
# 5            singing and dancing
# 9                         acting
# 13                           six
# 16                   influential
# 19      her mother's maiden name
# ...                          ...
# 161151                   western
# 161157           near-threatened
# 161158        ban trophy hunting
# 161159        ban trophy hunting
# 161160        ban trophy hunting
#
#                                     potential_UQ_question  \
# 5       What areas didn't Beyonce compete in when she ...
# 9       After her second solo album, what other entert...
# 13      To set the record for Grammys, how many didn't...
# 16      Time magazine didn't name her one of the most ...
# 19               Where did Beyonce not get her name from?
# ...                                                   ...
# 161151  What part of North America didn't the bison live?
# 161157                     What don't bison still remain?
# 161158        What Botswana was resently forced to don't?
# 161159       What Botswana was resently not forced to do?
# 161160        What Botswana wasn't resently forced to do?
#
#                            model_name_list  len
# 5       [model 4, electra, roberta, retro]    4
# 9       [model 4, electra, roberta, retro]    4
# 13      [model 4, electra, roberta, retro]    4
# 16      [model 4, electra, roberta, retro]    4
# 19      [model 4, electra, roberta, retro]    4
# ...                                    ...  ...
# 161151  [model 4, electra, roberta, retro]    4
# 161157  [model 4, electra, roberta, retro]    4
# 161158  [model 4, electra, roberta, retro]    4
# 161159  [model 4, electra, roberta, retro]    4
# 161160  [model 4, electra, roberta, retro]    4
#
# [45053 rows x 7 columns]

# %%
# Define the conditions you want to check
conditions = [
    ('len >= 1', new_df['len'] >= 1),
    ('len == 3', new_df['len'] == 3),
    ('len == 4', new_df['len'] == 4),
    ('len == 5', new_df['len'] == 5),
    ('len == 6', new_df['len'] == 6),
    ('len >= 3', new_df['len'] >= 3),
    ('len >= 4', new_df['len'] >= 4),
    ('len >= 5', new_df['len'] >= 5)
]

# Initialize an empty dictionary to hold the results
condition_counts = {}

# Iterate over each condition
for condition_name, condition in conditions:
    # Filter the DataFrame based on the current condition
    filtered_df = new_df[condition]
    
    # Count the number of records that meet the condition
    count = filtered_df.shape[0]
    
    # Store the count in the dictionary
    condition_counts[condition_name] = count

# Display the counts for each condition
for condition_name, count in condition_counts.items():
    print(f"Number of records where {condition_name}: {count}")
# Out:
# Number of records where len >= 1: 151371
# Number of records where len == 3: 59394
# Number of records where len == 4: 36691
# Number of records where len == 5: 8360
# Number of records where len == 6: 2
# Number of records where len >= 3: 104447
# Number of records where len >= 4: 45053
# Number of records where len >= 5: 8362
